# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append('../')   
import numpy as np
import pandas as pd
from model.erroneousPreference import erroneousPreference
from model.erroneousChoice import erroneousChoice
from kernel import jaxrbf, RBF, Linear, LinearRBF
from utility import  paramz
from sklearn.model_selection import train_test_split,GroupShuffleSplit
# for plotting
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

import torch
from botorch.utils.multi_objective import is_non_dominated

from scipy.linalg import block_diag
import itertools

def BlockRBF(X1,X2,params,single=True):
    ix1=X1[:,-1]
    ix2=X2[:,-1]
    ind=np.array([70]) #35,45,55
    #print(ind)
    numblocks = len(ind)
    pp={'lengthscale':params['lengthscale']}
    pp['variance']=params['variance_0']
    B1 = np.zeros((X1.shape[0],X2.shape[0]))
    rows,cols=zip(*itertools.product(np.where(ix1==ind[0])[0].tolist(),np.where(ix2==ind[0])[0].tolist()))
    B1[rows,cols]=RBF(X1[ix1==ind[0],0:-1],X2[ix2==ind[0],0:-1],pp,diag_=False).flatten()
    for i in range(1,numblocks):
        pp={'lengthscale':params['lengthscale']}
        if single==True:
            pp['variance']=params['variance_0']
        else:
            pp['variance']=params['variance_'+str(i)]
        rows,cols=zip(*itertools.product(np.where(ix1==ind[i])[0].tolist(),np.where(ix2==ind[i])[0].tolist()))
        B1[rows,cols]=RBF(X1[ix1==ind[i],0:-1],X2[ix2==ind[i],0:-1],pp,diag_=False).flatten()

    return B1

def is_pareto(X):
    return is_non_dominated(torch.from_numpy(X),deduplicate=False)
    
def extract_CA_RA(df,X,cols):
    IndexMat=[]
    IndCh=[]
    CA = []
    RA = []
    for el in np.unique(df.case.values):
        d = df[df.case==el]
        ind=[]
        row=d[cols].values
        #print(row)
        indc=[]
        indm=[]
        for r in range(row.shape[0]):
            #print(repr(rowi))
            #print(np.isin(X, row[r]))
            #print(row[r])
            j = np.where( np.isin(X, row[r]).all(axis=1))[0][0]
            #print(j)
            #print(d['choice'].iloc[r])
            indm.append(j)
            indc.append(d['choice'].iloc[r])
                
        IndexMat.append(indm)
        IndCh.append(indc)
    IndexMat=np.vstack(IndexMat)
    ind=np.argsort(IndexMat,axis=1)
    IndCh=np.vstack(IndCh)
    for i in range(ind.shape[0]):
        IndexMat[i,:]=IndexMat[i,ind[i,:]]
        IndCh[i,:]=IndCh[i,ind[i,:]]
    return IndexMat,IndCh

def make_CA_RA(IndexMat,IndCh):
    CA=[]
    RA=[]
    for c in range(IndexMat.shape[0]):
        indr=IndexMat[c,:]
        chrow=IndCh[c,:]
        indn0=np.where(chrow>0)[0]
        ind0=np.where(chrow==0)[0]
        CA.append(indr[indn0].tolist())
        RA.append(indr[ind0].tolist())
        
    return CA,RA

def make_pref_or_choices(IndexMat,IndCh, typeR='pref',drop_duplicates=False):
    num=IndexMat.shape[1]
    if typeR=='pref':
        
        if drop_duplicates:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh])).drop_duplicates()
        else:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh]))
        IndexMat=dfm.iloc[:,0:num].values
        IndCh=dfm.iloc[:,num:].values
        CA,RA = make_CA_RA(IndexMat,IndCh)
        
        CA=np.vstack(CA)
        RA = np.vstack(RA)
        All=[]
        for i in range(RA.shape[1]):
            All=All+list(zip(CA[:,0],RA[:,i].tolist()))
        All=np.vstack(All)
        CA=[[All[i,0]] for i in range(All.shape[0])]
        RA=[[All[i,1]] for i in range(All.shape[0])]
    elif typeR=='pref_choice':
        if drop_duplicates:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh])).drop_duplicates()
        else:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh]))
        IndexMat=dfm.iloc[:,0:num].values
        IndCh=dfm.iloc[:,num:].values
        CA,RA = make_CA_RA(IndexMat,IndCh)
    elif typeR=='choice':
        dfm = pd.DataFrame(np.hstack([IndexMat,IndCh])).groupby(np.arange(num).tolist()).mean().reset_index()
        IndexMat=dfm.iloc[:,0:num].values
        IndCh=dfm.iloc[:,num:].values
        CA,RA = make_CA_RA(IndexMat,IndCh)
    return CA,RA
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Mode Canada
#
# We consider a dataset including the choices made by subjects regarding their preferred transport mode for the Montreal-Toronto corridor.
# There are four transport modes (air, bus, car and train) and we have the following information about the journey: `dist`  the distance
# of the trip, `cost`  the monetary cost, `ivt`  the in-vehicle-time, `ovt`  the out-of-vehicle
# time, `freq` the frequency and `noalt`  the number of available alternatives. There are also  subject specific variables: `income`  the household income and `urban`  an indicator variable for trips which have a large city at the origin or the destination.
# The dataset is shown below. Each `case` corresponds to a different choice set for an individual.
# The dataset includes  4221 different  transport modes and  4322 cases (leading to 15520 rows). This dataset will allow us to explore how the various models we have previously introduced can be applied to address diverse choice tasks.

# %%
df = pd.read_csv("datasets/ModeCanada.csv",index_col=0)
cols_cov=['dist', 'cost', 'ivt', 'ovt', 'freq','income']
num=4
num_income=3
df = df[(df.noalt==num)& ((df.urban==1)  )  & (df.income==70)]
df.head(8)
# Out:
#      case    alt  choice  dist    cost  ivt  ovt  freq  income  urban  noalt
# 396   132  train       1   365   60.85  237   94     4      70      1      4
# 397   132    air       0   365  151.20   56   77     9      70      1      4
# 398   132    bus       0   365   27.82  301   83     8      70      1      4
# 399   132    car       0   365   69.35  245    0     0      70      1      4
# 408   135  train       0   365   60.85  237   94     4      70      1      4
# 409   135    air       1   365  151.20   56   77     9      70      1      4
# 410   135    bus       0   365   27.82  301   83     8      70      1      4
# 411   135    car       0   365   69.35  245    0     0      70      1      4

# %% [markdown]
# We will only focus on the subset of the choices
# with `noalt=4`, namely those for which four transportation modes are available. Above, we can see two cases belonging to this subset.
#
# In this first analysis, we will disregard subject-specific variables (income and urban), approaching the problem as an object-preference problem. Therefore, we have selected the subset of subjects with income=70 and urban=1 (a total of $679$ cases).
# Since subjects make always a transportation-mode choice, instances where the same individuals select both transportation modes cannot occur. In simpler terms, we will not observe instances of indifference (for instance if several transportation modes have closely ranked utilities for the subject), nor will we observe cases of incompatibility (where a subject makes both choices).
#
# We will select a RBF kernel for the model.

# %%
Kernel = RBF #RBF|Linear| BlockRBF
typeR='pref'

# %%
n_splits=1
splitter = GroupShuffleSplit(train_size=0.7, n_splits=n_splits, random_state = 1)
split = splitter.split(df, groups=df['case'])
Res=[]
for cv in range(n_splits):
    print(cv)
    ind_train, ind_test = next(split)
    df_train = df.iloc[ind_train,:].reset_index(drop=True)
    df_test  = df.iloc[ind_test,:].reset_index(drop=True)
    X_tr = np.unique(df_train[cols_cov].values,axis=0)
    X_te = np.unique(df_test[cols_cov].values,axis=0)
    
    #train set
    IndexMat,IndCh=extract_CA_RA(df_train,X_tr,cols_cov)
    CA_tr,RA_tr=make_pref_or_choices(IndexMat,IndCh,typeR=typeR)
    #test set
    IndexMat,IndCh=extract_CA_RA(df_test,X_te,cols_cov)
    CA_te,RA_te=make_pref_or_choices(IndexMat,IndCh,typeR=typeR)
    #standard scaling
    if 'income' in cols_cov:
        scalerx=StandardScaler().fit(X_tr[:,0:-1])
        X_trasf_tr = np.hstack([scalerx.transform(X_tr[:,0:-1]),X_tr[:,[-1]]])
        X_trasf_te = np.hstack([scalerx.transform(X_te[:,0:-1]),X_te[:,[-1]]])
    else:
        scalerx=StandardScaler().fit(X_tr)
        X_trasf_tr = scalerx.transform(X_tr)
        X_trasf_te = scalerx.transform(X_te)
    
    
    if typeR=='pref':
        # Data dictionary
        data = {}
        data["Pairs"]  = np.hstack([CA_tr,RA_tr])
        data["X"] = X_trasf_tr
        # define kernel and hyperparams
        
        params={}
        #kernel parameter dictionary
        if Kernel==RBF:
            params={'lengthscale': {'value':1.0*np.ones(data["X"].shape[1],float), 
                                    'range':np.vstack([[0.1, 10.0]]*data["X"].shape[1]),
                                    'transform': paramz.logexp()},
                         'variance': {'value':np.array([1.0]), 
                                    'range':np.vstack([[0.01, 10.0]]),
                                    'transform': paramz.logexp()}
                      }
        elif Kernel==Linear:
            params['variance']={'value':0.5+np.random.rand(1,data["X"].shape[1]) ,
                                        'range':np.vstack([[1e-6, 40.0]]*data["X"].shape[1]),
                                        'transform': paramz.logexp()}
        elif Kernel==BlockRBF:
            params={'lengthscale': {'value':1.0*np.ones(data["X"].shape[1]-1,float), 
                                    'range':np.vstack([[0.1, 10.0]]*(data["X"].shape[1]-1)),
                                    'transform': paramz.logexp()}
                      }
            for ni in range(num_income):
                params['variance_'+str(ni)]={'value':np.array([1.0]), 
                                        'range':np.vstack([[0.01, 10.0]]),
                                        'transform': paramz.logexp()}
            
    
        #define preference model 
        model = erroneousPreference(data,Kernel,params)
        #compute hyperparameters
        model.optimize_hyperparams(num_restarts=3)
        print(model.params)
        
        #sample from posterior
        model.sample(nsamples=1000, tune=100)
        #predicted samples
        predictions = model.predict(X_trasf_te)
        meanu = np.mean(predictions,axis=1)
        Acc = []
        for i in range(len(CA_te)):
            if meanu[CA_te[i]]>np.max(meanu[RA_te[i]]):
                Acc.append(1.0)
            else:
                Acc.append(0.0)
        Res.append(np.mean(Acc))
    else:
        dimA = num
        #choice data
        data={'X': X_trasf_tr,#objects
              'CA': CA_tr,#choiced objects
              'RA': RA_tr,#rejected objects
              'dimA':dimA# dimension of the choice set
                  }
        # number of latent utilities
        latent_dim=1
        
        # define kernel 
        Kernel = jaxrbf.RBF
        #hyperparameters of the kernel
        params = {'lengthscale_0': {'value':0.8*np.ones(data["X"].shape[1],float), 
                                    'range':np.vstack([[0.1, 5.0]]*data["X"].shape[1]),
                                    'transform': paramz.logexp()},
                   'variance_0': {'value':np.array([5.0]), 
                                    'range':np.vstack([[0.05, 50.0]]),
                                    'transform': paramz.logexp()}
                      }
        
        
        
        # define choice model 
        model = erroneousChoice(data,Kernel,params,latent_dim,jitter=1e-6,typeR="pseudo")
        # compute variational inference and estimate hyperparameters
        
        model.optimize_hyperparams(niterations=1000,kernel_hypers_fixed=False, 
                                   #init_f=np.zeros(2*X.shape[0]),
                                   diagonal=True)
        print(model.params)
        predictions = model.predict_VI(X_trasf_te)
        
        meanu=predictions[0]
        Sigmau=predictions[1]
        meanu = meanu.reshape(latent_dim,X_trasf_te.shape[0]).T
        meanu=np.array(meanu)
        Acc = []
        for i in range(len(CA_te)):
            for j in range(len(RA_te[i])):
                Acc=Acc+np.array([np.any(meanu[CA_te[i],:]-meanu[RA_te[i][j]]>0)]).tolist()
               
            Acc=Acc+is_pareto(np.array(meanu[CA_te[i],:])).tolist()
        
        Res.append(np.mean(Acc))
    
    print(np.mean(Res))
# Out:
# 0
#   0%|          | 0/200 [00:00<?, ?it/s]
# Iteration 0  -368.977855179313
#   0%|          | 0/200 [00:00<?, ?it/s]
# Iteration 1  -372.35829078926827
#   0%|          | 0/200 [00:00<?, ?it/s]
# Iteration 2  -385.62544942318084
# {'lengthscale': {'value': array([1.12689347, 0.6065922 , 2.4761737 , 1.41549984, 0.56697503,
#        1.        ]), 'range': array([[ 0.1, 10. ],
#        [ 0.1, 10. ],
#        [ 0.1, 10. ],
#        [ 0.1, 10. ],
#        [ 0.1, 10. ],
#        [ 0.1, 10. ]]), 'transform': <utility.paramz.logexp object at 0x7f9c540a8450>}, 'variance': {'value': array([5.31318491]), 'range': array([[ 0.01, 10.  ]]), 'transform': <utility.paramz.logexp object at 0x7f9b3635f9d0>}}
# 100%|███████████████████████████████████████| 1100/1100 [00:57<00:00, 19.22it/s]
# 0.8970588235294118

# %% [markdown]
# Accuracy:

# %%
np.mean(Res)
# Out:
# 0.8970588235294118

# %%
from scipy.stats import norm
import arviz as az
az.plot_dist(predictions[51],color='C0',label="bus")
az.plot_dist(predictions[52],color='C1',label="car")
az.plot_dist(predictions[53],color='C2',label="train")
az.plot_dist(predictions[54],color='C3',label="air")
plt.grid()
#az.plot_dist(predictions[0]-predictions[2])
plt.xlabel("u",fontsize=16)
plt.ylabel("Posterior",fontsize=16)
#plt.savefig("figures/trasp_u_rbf.pdf")
# Out:
# Text(0, 0.5, 'Posterior')

# %%
dimA = num
#choice data
data={'X': X_trasf_tr,#objects
      'CA': CA_tr,#choiced objects
      'RA': RA_tr,#rejected objects
      'dimA':dimA# dimension of the choice set
          }

# number of latent utilities
latent_dim=2

# define kernel 
Kernel = jaxrbf.RBF
#hyperparameters of the kernel
params = {'lengthscale_0': {'value':0.8*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 5.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_0': {'value':np.array([1.0]), 
                            'range':np.vstack([[0.05, 50.0]]),
                            'transform': paramz.logexp()},
            'lengthscale_1': {'value':0.8*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 5.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_1': {'value':np.array([1.0]), 
                            'range':np.vstack([[0.05, 50.0]]),
                            'transform': paramz.logexp()}
              }



# define choice model 
model = erroneousChoice(data,Kernel,params,latent_dim,jitter=1e-6,typeR="pseudo")
# compute variational inference and estimate hyperparameters
model.optimize_hyperparams(niterations=5000,kernel_hypers_fixed=False, 
                           #init_f=np.zeros(2*X.shape[0]),
                           diagonal=False)
print(model.params)
# Out:
# /home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py:62: RuntimeWarning: invalid value encountered in matmul
#   IKxx = L_inv@L_inv.T
# 899250.9245934262
#  lower bound 924.9109901742497:   4%|▎         | 183/5000 [55:23<24:17:57, 18.16s/it]
#  lower bound 1453.7011551774797:   0%|          | 25/5000 [26:55<89:18:01, 64.62s/it]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 523.3407424737136
#  lower bound 3200387.472693111:   3%|▎         | 172/5000 [10:34<5:17:00,  3.94s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-06f1f6b7eb1a> in <module>
#      32 model = erroneousChoice(data,Kernel,params,latent_dim,jitter=1e-6,typeR="pseudo")
#      33 # compute variational inference and estimate hyperparameters
# ---> 34 model.optimize_hyperparams(niterations=5000,kernel_hypers_fixed=False,
#      35                            #init_f=np.zeros(2*X.shape[0]),
#      36                            diagonal=False)
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/abstractModel.py in optimize_hyperparams(self, num_restarts, niterations, kernel_hypers_fixed, init_f, diagonal)
#      45                                           self.params,
#      46                                           self._log_likelihood)
# ---> 47             infer.optimize(niterations,
#      48                            kernel_hypers_fixed=kernel_hypers_fixed,
#      49                            init_f=init_f,diagonal=diagonal)
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py in optimize(self, niterations, progress, kernel_hypers_fixed, init_f, diagonal)
#     260
#     261         loglike =self._log_like()
# --> 262         f, Sigma, log_kernel_hypers, advi_params = self.advi(niterations,loglike,
#     263                                                              init_params_kernel,
#     264                                                              kernel_hypers_fixed=kernel_hypers_fixed,
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py in advi(self, niterations, loglike, init_params_kernel, progress, kernel_hypers_fixed, diagonal, init_f)
#     217
#     218             if t<int(0.1*niterations):
# --> 219                  opt_state = update_start(t, opt_state)
#     220             else:
#     221                 opt_state = update(t, opt_state)
#
# ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/example_libraries/optimizers.py in <lambda>(data, xs)
#     118     OptimizerState,
#     119     lambda xs: ((xs.packed_state,), (xs.tree_def, xs.subtree_defs)),
# --> 120     lambda data, xs: OptimizerState(xs[0], data[0], data[1]))  # type: ignore[index]
#     121
#     122
#
# KeyboardInterrupt:

# %%
import jax
? jax.numpy.linalg.solve

# %%
np.tril_indices(3)
# Out:
# (array([0, 1, 1, 2, 2, 2]), array([0, 0, 1, 0, 1, 2]))

# %%
Accuracy=0.7855297157622739

{'lengthscale_0': {'value': array([0.19070994, 0.08555967, 0.07452685, 0.32012958, 0.37082475]), 'range': array([[0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ]]), 'transform': <utility.paramz.logexp object at 0x7f0d75618e80>}, 'variance_0': {'value': array([2.15207161]), 'range': array([[ 0.05, 50.  ]]), 'transform': <utility.paramz.logexp object at 0x7f0d75618eb0>}, 'lengthscale_1': {'value': array([0.17421087, 0.06796804, 0.02839068, 0.26718789, 0.34512444]), 'range': array([[0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ]]), 'transform': <utility.paramz.logexp object at 0x7f0d5d3b0040>}, 'variance_1': {'value': array([2.06409303]), 'range': array([[ 0.05, 50.  ]]), 'transform': <utility.paramz.logexp object at 0x7f0d5d3b00d0>}}

# %%
import pickle

a = {'hello': 'world'}

with open('ModeCanada_choice3_latet_full', 'wb') as handle:
    pickle.dump(model.meanVI, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Out:
# 0.7829457364341085

# %%
from scipy.stats import norm

mean=meanu[CA_te[0],0]
std_dev=np.sqrt(Sigmau[CA_te[0],CA_te[0]])
mean1=meanu[RA_te[0],0]
std_dev1=np.sqrt(Sigmau[RA_te[0],RA_te[0]])
xx = np.linspace(mean - 7*std_dev, mean + 4*std_dev, 1000)
# Calculate the corresponding y-axis values using the Gaussian PDF formula
yy = norm.pdf(xx, mean, std_dev)
yy1 = norm.pdf(xx, mean1, std_dev1)
# Plot the Gaussian PDF
plt.plot(xx, yy,color='C0',label="p(u$_1$)")
plt.plot(xx, yy1[:,0],color='C1',label="p(u$_2$)")
plt.plot(xx, yy1[:,1],color='C2',label="p(u$_3$)")
plt.xlabel('u',fontsize=16)
#plt.ylabel('Probability Density')
plt.legend(fontsize=16)
plt.grid(True)
plt.show()
#plt.savefig("modecanada_choice3.pdf")

# %%
yy1
# Out:
# array([[0.00268041, 0.00400115],
#        [0.00273143, 0.00408216],
#        [0.00278332, 0.00416461],
#        ...,
#        [0.00182275, 0.00015744],
#        [0.00178724, 0.00015331],
#        [0.00175236, 0.00014928]])

# %%
Sigmau[CA_te[0],CA_te[0]]
# Out:
# Array([0.69851636], dtype=float64)

# %%
# Large format
def make_large(df,num):
    dfl = df[df.noalt==num].copy()
    dfl['s']=dfl.groupby(['case']).cumcount()+1
    dfl=dfl.set_index(['s','case']).unstack(0)
    dfl.columns=[f"{x}{y}" for x,y in dfl.columns]
    dfl.drop(columns=["noalt"+str(i) for i in range(1,num+1)],inplace=True)
    return dfl.reset_index()
dfl = make_large(df,num)
cols=[]
for i in range(1,num+1):
    cols=cols+['dist'+str(i), 'cost'+str(i), 'ivt'+str(i), 'ovt'+str(i),'freq'+str(i)]
#dfl['target']=0*dfl['choice1']+1*dfl['choice2']+3*dfl['choice3']+2*dfl['choice4']
dfl[cols].duplicated(keep=False)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 147     True
# 148    False
# 149    False
# 150    False
# 151    False
# Length: 152, dtype: bool

# %%
df
# Out:
#        case    alt  choice  dist    cost  ivt  ovt  freq  income  urban  noalt
# 424     139  train       1   354   59.00  237   69     4      35      1      4
# 425     139    air       0   354  155.80   56   97     9      35      1      4
# 426     139    bus       0   354   27.34  301   68     8      35      1      4
# 427     139    car       0   354   67.26  231    0     0      35      1      4
# 452     146  train       1   354   59.00  237   69     4      35      1      4
# ...     ...    ...     ...   ...     ...  ...  ...   ...     ...    ...    ...
# 14551  4063    car       1   287   54.53  225    0     0      35      1      4
# 14572  4069  train       0   231   45.90  193   78     3      35      1      4
# 14573  4069    air       0   231  146.90   46  101    16      35      1      4
# 14574  4069    bus       0   231   25.21  186   81    24      35      1      4
# 14575  4069    car       1   231   43.89  161    0     0      35      1      4
#
# [608 rows x 11 columns]

# %%
df.shape
# Out:
# (608, 11)

# %%
len(CA_tr)+len(CA_te)
# Out:
# 2037

# %%
cols=[]
for i in range(1,3):
    cols=cols+['dist'+str(i), 'cost'+str(i), 'ivt'+str(i), 'ovt'+str(i),'freq'+str(i)]
dfl = pd.DataFrame(columns=['case']+cols+['target'])
for c in np.unique(df.case.values):
    d = df[df.case==c]
    ind1=np.where(d.choice==1)[0]
    for i in np.setdiff1d(np.arange(num),ind1):
        if np.random.rand(1)<0.5:
            ii=ind1[0]
            jj=i
            t=1
        else:
            ii=i
            jj=ind1[0]
            t=0
        row=np.hstack([np.array([c]),d[cols_cov].iloc[ii].values,d[cols_cov].iloc[jj].values,np.array([t])])[None,:]
        dfl = pd.concat([dfl,pd.DataFrame(row,columns=dfl.columns)],axis=0)
    
dfl.reset_index(drop=True,inplace=True)
dfl
# Out:
#        case  dist1   cost1   ivt1   ovt1  freq1  dist2   cost2   ivt2   ovt2  \
# 0     139.0  354.0  155.80   56.0   97.0    9.0  354.0   59.00  237.0   69.0
# 1     139.0  354.0   27.34  301.0   68.0    8.0  354.0   59.00  237.0   69.0
# 2     139.0  354.0   67.26  231.0    0.0    0.0  354.0   59.00  237.0   69.0
# 3     146.0  354.0   59.00  237.0   69.0    4.0  354.0  155.80   56.0   97.0
# 4     146.0  354.0   59.00  237.0   69.0    4.0  354.0   27.34  301.0   68.0
# ..      ...    ...     ...    ...    ...    ...    ...     ...    ...    ...
# 451  4063.0  287.0  154.90   46.0  165.0   16.0  287.0   54.53  225.0    0.0
# 452  4063.0  287.0   20.86  115.0   95.0    8.0  287.0   54.53  225.0    0.0
# 453  4069.0  231.0   43.89  161.0    0.0    0.0  231.0   45.90  193.0   78.0
# 454  4069.0  231.0   43.89  161.0    0.0    0.0  231.0  146.90   46.0  101.0
# 455  4069.0  231.0   25.21  186.0   81.0   24.0  231.0   43.89  161.0    0.0
#
#      freq2  target
# 0      4.0     0.0
# 1      4.0     0.0
# 2      4.0     0.0
# 3      9.0     1.0
# 4      8.0     1.0
# ..     ...     ...
# 451    0.0     0.0
# 452    0.0     0.0
# 453    3.0     1.0
# 454   16.0     1.0
# 455    0.0     0.0
#
# [456 rows x 12 columns]

# %%
dfl.shape
# Out:
# (2037, 12)

# %%
import pandas as pd
import numpy as np 
from sklearn.ensemble import RandomForestClassifier

# %%
splitter = GroupShuffleSplit(train_size=0.7, n_splits=n_splits, random_state = 1)
split = splitter.split(df, groups=df['case'])
Res=[]
for cv in range(n_splits):
    print(cv)
    ind_train, ind_test = next(split)
    
    dfl_train=dfl[dfl.case.isin(np.unique(df['case'].iloc[ind_train]))]
    dfl_test=dfl[dfl.case.isin(np.unique(df['case'].iloc[ind_test]))]
    Xl_train = dfl_train[cols].values
    yl_train=dfl_train['target'].values
    Xl_test = dfl_test[cols].values
    yl_test=dfl_test['target'].values

    scalerxl=StandardScaler().fit(Xl_train)
    Xl_train_trasf=scalerxl.transform(Xl_train)
    Xl_test_trasf=scalerxl.transform(Xl_test)
    
    eval_set = [(Xl_train_trasf, yl_train),(Xl_test_trasf, yl_test)]
    classif =  RandomForestClassifier(random_state=0) 
    classif.fit(Xl_train_trasf, yl_train) 
    ypred_x= classif.predict(Xl_test_trasf)
    Res.append(accuracy_score(ypred_x,yl_test)
    )
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
np.mean(Res)
# Out:
# 0.881159420289855

# %%
Res
# Out:
# [0.9202898550724637,
#  0.8405797101449275,
#  0.927536231884058,
#  0.8695652173913043,
#  0.8478260869565217]

# %%
len(CA_tr)
# Out:
# 1425

# %%
CA_tr
# Out:
# [[351],
#  [352],
#  [342],
#  [342],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [343],
#  [343],
#  [343],
#  [348],
#  [348],
#  [347],
#  [347],
#  [354],
#  [354],
#  [352],
#  [318],
#  [328],
#  [328],
#  [276],
#  [275],
#  [298],
#  [299],
#  [288],
#  [288],
#  [284],
#  [152],
#  [114],
#  [115],
#  [610],
#  [641],
#  [586],
#  [560],
#  [109],
#  [102],
#  [101],
#  [101],
#  [101],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [90],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [95],
#  [93],
#  [98],
#  [98],
#  [97],
#  [624],
#  [626],
#  [626],
#  [626],
#  [626],
#  [626],
#  [626],
#  [625],
#  [638],
#  [89],
#  [89],
#  [89],
#  [6],
#  [6],
#  [33],
#  [43],
#  [26],
#  [9],
#  [505],
#  [437],
#  [437],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [492],
#  [510],
#  [510],
#  [510],
#  [510],
#  [510],
#  [509],
#  [509],
#  [518],
#  [514],
#  [514],
#  [514],
#  [514],
#  [514],
#  [514],
#  [522],
#  [378],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [442],
#  [462],
#  [462],
#  [462],
#  [462],
#  [551],
#  [551],
#  [554],
#  [554],
#  [554],
#  [554],
#  [554],
#  [554],
#  [576],
#  [572],
#  [572],
#  [577],
#  [577],
#  [577],
#  [577],
#  [577],
#  [575],
#  [578],
#  [590],
#  [390],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [460],
#  [478],
#  [478],
#  [478],
#  [478],
#  [478],
#  [598],
#  [486],
#  [486],
#  [486],
#  [145],
#  [268],
#  [257],
#  [407],
#  [374],
#  [618],
#  [555],
#  [650],
#  [679],
#  [679],
#  [67],
#  [67],
#  [67],
#  [66],
#  [66],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [236],
#  [236],
#  [306],
#  [306],
#  [324],
#  [324],
#  [324],
#  [324],
#  [323],
#  [380],
#  [380],
#  [494],
#  [332],
#  [366],
#  [455],
#  [482],
#  [402],
#  [530],
#  [620],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [646],
#  [658],
#  [660],
#  [662],
#  [662],
#  [666],
#  [688],
#  [75],
#  [74],
#  [251],
#  [252],
#  [250],
#  [315],
#  [397],
#  [502],
#  [340],
#  [339],
#  [418],
#  [418],
#  [538],
#  [634],
#  [542],
#  [568],
#  [568],
#  [546],
#  [546],
#  [606],
#  [670],
#  [670],
#  [674],
#  [630],
#  [79],
#  [256],
#  [256],
#  [335],
#  [425],
#  [654],
#  [552],
#  [680],
#  [684],
#  [444],
#  [444],
#  [444],
#  [448],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [469],
#  [564],
#  [580],
#  [580],
#  [580],
#  [581],
#  [451],
#  [451],
#  [468],
#  [474],
#  [473],
#  [597],
#  [602],
#  [498],
#  [498],
#  [614],
#  [370],
#  [370],
#  [370],
#  [370],
#  [370],
#  [525],
#  [362],
#  [361],
#  [358],
#  [357],
#  [1],
#  [25],
#  [25],
#  [165],
#  [210],
#  [210],
#  [192],
#  [436],
#  [70],
#  [124],
#  [124],
#  [124],
#  [242],
#  [150],
#  [134],
#  [55],
#  [242],
#  [386],
#  [386],
#  [385],
#  [385],
#  [392],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [393],
#  [393],
#  [393],
#  [272],
#  [246],
#  [279],
#  [280],
#  [159],
#  [409],
#  [414],
#  [80],
#  [139],
#  [105],
#  [105],
#  [124],
#  [131],
#  [124],
#  [139],
#  [311],
#  [311],
#  [303],
#  [303],
#  [205],
#  [202],
#  [202],
#  [202],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [216],
#  [229],
#  [224],
#  [224],
#  [13],
#  [13],
#  [161],
#  [158],
#  [170],
#  [170],
#  [170],
#  [171],
#  [169],
#  [169],
#  [169],
#  [169],
#  [169],
#  [169],
#  [40],
#  [40],
#  [183],
#  [178],
#  [18],
#  [18],
#  [18],
#  [294],
#  [294],
#  [176],
#  [176],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [221],
#  [261],
#  [264],
#  [262],
#  [49],
#  [49],
#  [49],
#  [49],
#  [211],
#  [211],
#  [211],
#  [211],
#  [211],
#  [211],
#  [426],
#  [426],
#  [18],
#  [294],
#  [294],
#  [117],
#  [191],
#  [191],
#  [191],
#  [265],
#  [60],
#  [176],
#  [191],
#  [191],
#  [60],
#  [49],
#  [426],
#  [32],
#  [202],
#  [229],
#  [351],
#  [352],
#  [342],
#  [342],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [343],
#  [343],
#  [343],
#  [348],
#  [348],
#  [347],
#  [347],
#  [354],
#  [354],
#  [352],
#  [318],
#  [328],
#  [328],
#  [276],
#  [275],
#  [298],
#  [299],
#  [288],
#  [288],
#  [284],
#  [152],
#  [114],
#  [115],
#  [610],
#  [641],
#  [586],
#  [560],
#  [109],
#  [102],
#  [101],
#  [101],
#  [101],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [90],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [95],
#  [93],
#  [98],
#  [98],
#  [97],
#  [624],
#  [626],
#  [626],
#  [626],
#  [626],
#  [626],
#  [626],
#  [625],
#  [638],
#  [89],
#  [89],
#  [89],
#  [6],
#  [6],
#  [33],
#  [43],
#  [26],
#  [9],
#  [505],
#  [437],
#  [437],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [493],
#  [492],
#  [510],
#  [510],
#  [510],
#  [510],
#  [510],
#  [509],
#  [509],
#  [518],
#  [514],
#  [514],
#  [514],
#  [514],
#  [514],
#  [514],
#  [522],
#  [378],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [443],
#  [442],
#  [462],
#  [462],
#  [462],
#  [462],
#  [551],
#  [551],
#  [554],
#  [554],
#  [554],
#  [554],
#  [554],
#  [554],
#  [576],
#  [572],
#  [572],
#  [577],
#  [577],
#  [577],
#  [577],
#  [577],
#  [575],
#  [578],
#  [590],
#  [390],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [463],
#  [460],
#  [478],
#  [478],
#  [478],
#  [478],
#  [478],
#  [598],
#  [486],
#  [486],
#  [486],
#  [145],
#  [268],
#  [257],
#  [407],
#  [374],
#  [618],
#  [555],
#  [650],
#  [679],
#  [679],
#  [67],
#  [67],
#  [67],
#  [66],
#  [66],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [235],
#  [236],
#  [236],
#  [306],
#  [306],
#  [324],
#  [324],
#  [324],
#  [324],
#  [323],
#  [380],
#  [380],
#  [494],
#  [332],
#  [366],
#  [455],
#  [482],
#  [402],
#  [530],
#  [620],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [537],
#  [646],
#  [658],
#  [660],
#  [662],
#  [662],
#  [666],
#  [688],
#  [75],
#  [74],
#  [251],
#  [252],
#  [250],
#  [315],
#  [397],
#  [502],
#  [340],
#  [339],
#  [418],
#  [418],
#  [538],
#  [634],
#  [542],
#  [568],
#  [568],
#  [546],
#  [546],
#  [606],
#  [670],
#  [670],
#  [674],
#  [630],
#  [79],
#  [256],
#  [256],
#  [335],
#  [425],
#  [654],
#  [552],
#  [680],
#  [684],
#  [444],
#  [444],
#  [444],
#  [448],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [450],
#  [469],
#  [564],
#  [580],
#  [580],
#  [580],
#  [581],
#  [451],
#  [451],
#  [468],
#  [474],
#  [473],
#  [597],
#  [602],
#  [498],
#  [498],
#  [614],
#  [370],
#  [370],
#  [370],
#  [370],
#  [370],
#  [525],
#  [362],
#  [361],
#  [358],
#  [357],
#  [1],
#  [25],
#  [25],
#  [165],
#  [210],
#  [210],
#  [192],
#  [436],
#  [70],
#  [124],
#  [124],
#  [124],
#  [242],
#  [150],
#  [134],
#  [55],
#  [242],
#  [386],
#  [386],
#  [385],
#  [385],
#  [392],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [394],
#  [393],
#  [393],
#  [393],
#  [272],
#  [246],
#  [279],
#  [280],
#  [159],
#  [409],
#  [414],
#  [80],
#  [139],
#  [105],
#  [105],
#  [124],
#  [131],
#  [124],
#  [139],
#  [311],
#  [311],
#  [303],
#  [303],
#  [205],
#  [202],
#  [202],
#  [202],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [218],
#  [216],
#  [229],
#  [224],
#  [224],
#  [13],
#  [13],
#  [161],
#  [158],
#  [170],
#  [170],
#  [170],
#  [171],
#  [169],
#  [169],
#  [169],
#  [169],
#  [169],
#  [169],
#  [40],
#  [40],
#  [183],
#  [178],
#  [18],
#  [18],
#  [18],
#  [294],
#  [294],
#  [176],
#  [176],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [191],
#  [221],
#  [261],
#  [264],
#  [262],
#  [49],
#  [49],
#  [49],
#  [49],
#  [211],
#  [211],
#  [211],
#  [211],
#  [211],
#  [211],
#  [426],
#  [426],
#  [18],
#  [294],
#  [294],
#  [117],
#  [191],
#  [191],
#  [191],
#  [265],
#  [60],
#  [176],
#  [191],
#  [191],
#  [60],
#  [49],
#  [426],
#  [32],
#  [202],
#  [229],
#  [351],
#  [352],
#  [342],
#  [342],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [344],
#  [343],
#  [343],
#  [343],
#  [348],
#  [348],
#  [347],
#  [347],
#  [354],
#  [354],
#  [352],
#  [318],
#  [328],
#  [328],
#  [276],
#  [275],
#  [298],
#  [299],
#  [288],
#  [288],
#  [284],
#  [152],
#  [114],
#  [115],
#  [610],
#  [641],
#  [586],
#  [560],
#  [109],
#  [102],
#  [101],
#  [101],
#  [101],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  ...]

# %%
RA_tr
# Out:
# [[350],
#  [350],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [341],
#  [345],
#  [345],
#  [345],
#  [345],
#  [349],
#  [349],
#  [349],
#  [317],
#  [325],
#  [325],
#  [274],
#  [274],
#  [297],
#  [297],
#  [286],
#  [286],
#  [282],
#  [148],
#  [112],
#  [112],
#  [607],
#  [639],
#  [583],
#  [557],
#  [108],
#  [100],
#  [100],
#  [100],
#  [100],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [85],
#  [92],
#  [92],
#  [96],
#  [96],
#  [96],
#  [623],
#  [623],
#  [623],
#  [623],
#  [623],
#  [623],
#  [623],
#  [623],
#  [635],
#  [86],
#  [86],
#  [86],
#  [4],
#  [4],
#  [35],
#  [44],
#  [24],
#  [8],
#  [503],
#  [430],
#  [430],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [488],
#  [507],
#  [507],
#  [507],
#  [507],
#  [507],
#  [507],
#  [507],
#  [515],
#  [511],
#  [511],
#  [511],
#  [511],
#  [511],
#  [511],
#  [519],
#  [375],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [439],
#  [457],
#  [457],
#  [457],
#  [457],
#  [549],
#  [549],
#  [549],
#  [549],
#  [549],
#  [549],
#  [549],
#  [549],
#  [570],
#  [569],
#  [569],
#  [569],
#  [569],
#  [569],
#  [569],
#  [569],
#  [569],
#  [571],
#  [587],
#  [387],
#  [456],
#  [456],
#  [456],
#  [456],
#  [456],
#  [456],
#  [456],
#  [456],
#  [456],
#  [475],
#  [475],
#  [475],
#  [475],
#  [475],
#  [592],
#  [483],
#  [483],
#  [483],
#  [144],
#  [266],
#  [254],
#  [403],
#  [371],
#  [615],
#  [548],
#  [647],
#  [676],
#  [676],
#  [65],
#  [65],
#  [65],
#  [65],
#  [65],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [234],
#  [305],
#  [305],
#  [321],
#  [321],
#  [321],
#  [321],
#  [321],
#  [379],
#  [379],
#  [487],
#  [329],
#  [363],
#  [452],
#  [479],
#  [399],
#  [527],
#  [619],
#  [531],
#  [531],
#  [531],
#  [531],
#  [531],
#  [531],
#  [531],
#  [531],
#  [643],
#  [655],
#  [659],
#  [659],
#  [659],
#  [663],
#  [685],
#  [73],
#  [73],
#  [249],
#  [249],
#  [249],
#  [313],
#  [395],
#  [499],
#  [337],
#  [337],
#  [415],
#  [415],
#  [532],
#  [631],
#  [539],
#  [565],
#  [565],
#  [543],
#  [543],
#  [603],
#  [667],
#  [667],
#  [671],
#  [627],
#  [78],
#  [253],
#  [253],
#  [333],
#  [421],
#  [651],
#  [547],
#  [675],
#  [681],
#  [438],
#  [438],
#  [438],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [446],
#  [465],
#  [561],
#  [579],
#  [579],
#  [579],
#  [579],
#  [445],
#  [445],
#  [464],
#  [471],
#  [471],
#  [591],
#  [599],
#  [495],
#  [495],
#  [611],
#  [367],
#  [367],
#  [367],
#  [367],
#  [367],
#  [523],
#  [359],
#  [359],
#  [355],
#  [355],
#  [0],
#  [23],
#  [23],
#  [164],
#  [207],
#  [207],
#  [186],
#  [431],
#  [69],
#  [123],
#  [123],
#  [123],
#  [238],
#  [149],
#  [133],
#  [54],
#  [239],
#  [383],
#  [383],
#  [383],
#  [383],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [391],
#  [270],
#  [245],
#  [278],
#  [278],
#  [156],
#  [404],
#  [411],
#  [77],
#  [137],
#  [104],
#  [104],
#  [121],
#  [120],
#  [122],
#  [138],
#  [309],
#  [309],
#  [301],
#  [301],
#  [200],
#  [200],
#  [200],
#  [200],
#  [215],
#  [215],
#  [215],
#  [215],
#  [215],
#  [215],
#  [215],
#  [227],
#  [223],
#  [223],
#  [12],
#  [12],
#  [157],
#  [157],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [168],
#  [39],
#  [39],
#  [182],
#  [173],
#  [16],
#  [16],
#  [16],
#  [290],
#  [290],
#  [172],
#  [172],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [187],
#  [219],
#  [259],
#  [259],
#  [259],
#  [47],
#  [47],
#  [47],
#  [47],
#  [208],
#  [208],
#  [208],
#  [208],
#  [208],
#  [208],
#  [419],
#  [419],
#  [17],
#  [291],
#  [291],
#  [116],
#  [189],
#  [189],
#  [189],
#  [260],
#  [59],
#  [174],
#  [188],
#  [188],
#  [58],
#  [48],
#  [420],
#  [31],
#  [201],
#  [228],
#  [352],
#  [351],
#  [343],
#  [343],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [342],
#  [346],
#  [346],
#  [346],
#  [346],
#  [351],
#  [351],
#  [351],
#  [319],
#  [326],
#  [326],
#  [275],
#  [276],
#  [299],
#  [298],
#  [287],
#  [287],
#  [283],
#  [153],
#  [113],
#  [113],
#  [608],
#  [640],
#  [584],
#  [558],
#  [110],
#  [101],
#  [102],
#  [102],
#  [102],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [87],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [88],
#  [93],
#  [94],
#  [97],
#  [97],
#  [98],
#  [625],
#  [624],
#  [624],
#  [624],
#  [624],
#  [624],
#  [624],
#  [624],
#  [636],
#  [87],
#  [87],
#  [87],
#  [5],
#  [5],
#  [36],
#  [45],
#  [28],
#  [10],
#  [504],
#  [433],
#  [433],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [490],
#  [508],
#  [508],
#  [508],
#  [508],
#  [508],
#  [508],
#  [508],
#  [516],
#  [512],
#  [512],
#  [512],
#  [512],
#  [512],
#  [512],
#  [520],
#  [376],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [441],
#  [459],
#  [459],
#  [459],
#  [459],
#  [553],
#  [553],
#  [551],
#  [551],
#  [551],
#  [551],
#  [551],
#  [551],
#  [574],
#  [575],
#  [575],
#  [572],
#  [572],
#  [572],
#  [572],
#  [572],
#  [572],
#  [573],
#  [588],
#  [388],
#  [458],
#  [458],
#  [458],
#  [458],
#  [458],
#  [458],
#  [458],
#  [458],
#  [458],
#  [476],
#  [476],
#  [476],
#  [476],
#  [476],
#  [593],
#  [484],
#  [484],
#  [484],
#  [146],
#  [267],
#  [255],
#  [405],
#  [372],
#  [616],
#  [550],
#  [648],
#  [677],
#  [677],
#  [66],
#  [66],
#  [66],
#  [67],
#  [67],
#  [236],
#  [236],
#  [236],
#  [236],
#  [236],
#  [236],
#  [236],
#  [236],
#  [235],
#  [235],
#  [307],
#  [307],
#  [322],
#  [322],
#  [322],
#  [322],
#  [322],
#  [381],
#  [381],
#  [489],
#  [330],
#  [364],
#  [453],
#  [480],
#  [400],
#  [528],
#  [621],
#  [533],
#  [533],
#  [533],
#  [533],
#  [533],
#  [533],
#  [533],
#  [533],
#  [644],
#  [656],
#  [661],
#  [660],
#  [660],
#  [664],
#  [686],
#  [74],
#  [75],
#  [250],
#  [250],
#  [251],
#  [314],
#  [396],
#  [500],
#  [338],
#  [338],
#  [416],
#  [416],
#  [534],
#  [632],
#  [540],
#  [566],
#  [566],
#  [544],
#  [544],
#  [604],
#  [668],
#  [668],
#  [672],
#  [628],
#  [81],
#  [255],
#  [255],
#  [334],
#  [424],
#  [652],
#  [550],
#  [677],
#  [682],
#  [440],
#  [440],
#  [440],
#  [449],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [448],
#  [467],
#  [562],
#  [581],
#  [581],
#  [581],
#  [580],
#  [447],
#  [447],
#  [466],
#  [472],
#  [472],
#  [594],
#  [600],
#  [496],
#  [496],
#  [612],
#  [368],
#  [368],
#  [368],
#  [368],
#  [368],
#  [524],
#  [360],
#  [360],
#  [356],
#  [356],
#  [2],
#  [27],
#  [27],
#  [166],
#  [209],
#  [209],
#  [195],
#  [432],
#  [71],
#  [128],
#  [128],
#  [128],
#  [240],
#  [151],
#  [135],
#  [56],
#  [241],
#  [384],
#  [384],
#  [384],
#  [384],
#  [393],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [392],
#  [271],
#  [247],
#  [280],
#  [279],
#  [160],
#  [406],
#  [412],
#  [82],
#  [140],
#  [106],
#  [106],
#  [127],
#  [124],
#  [126],
#  [141],
#  [310],
#  [310],
#  [302],
#  [302],
#  [202],
#  [204],
#  [204],
#  [204],
#  [216],
#  [216],
#  [216],
#  [216],
#  [216],
#  [216],
#  [217],
#  [231],
#  [225],
#  [225],
#  [14],
#  [14],
#  [158],
#  [161],
#  [169],
#  [169],
#  [169],
#  [169],
#  [170],
#  [170],
#  [170],
#  [170],
#  [170],
#  [170],
#  [41],
#  [41],
#  [184],
#  [176],
#  [19],
#  [19],
#  [19],
#  [292],
#  [292],
#  [175],
#  [175],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [190],
#  [220],
#  [262],
#  [261],
#  [261],
#  [50],
#  [50],
#  [50],
#  [50],
#  [212],
#  [212],
#  [212],
#  [212],
#  [212],
#  [212],
#  [422],
#  [422],
#  [20],
#  [293],
#  [293],
#  [118],
#  [193],
#  [193],
#  [193],
#  [262],
#  [61],
#  [177],
#  [194],
#  [194],
#  [62],
#  [51],
#  [423],
#  [34],
#  [203],
#  [230],
#  [353],
#  [353],
#  [344],
#  [344],
#  [343],
#  [343],
#  [343],
#  [343],
#  [343],
#  [343],
#  [343],
#  [344],
#  [344],
#  [344],
#  [347],
#  [347],
#  [348],
#  [348],
#  [352],
#  [352],
#  [354],
#  [320],
#  [327],
#  [327],
#  [277],
#  [277],
#  [300],
#  [300],
#  [289],
#  [289],
#  [285],
#  [155],
#  [115],
#  [114],
#  [609],
#  [642],
#  [585],
#  [559],
#  [111],
#  [103],
#  [103],
#  [103],
#  [103],
#  [90],
#  [90],
#  [90],
#  [90],
#  [90],
#  [90],
#  [90],
#  ...]
