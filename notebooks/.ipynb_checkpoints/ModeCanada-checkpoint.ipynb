# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append('../')   
import numpy as np
import pandas as pd
from model.erroneousPreference import erroneousPreference
from model.erroneousChoice_full import erroneousChoice
from kernel import jaxrbf, RBF, Linear, LinearRBF
from utility import  paramz
from sklearn.model_selection import train_test_split,GroupShuffleSplit
# for plotting
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score

def extract_CA_RA(df,X,cols):
    IndexMat=[]
    IndCh=[]
    CA = []
    RA = []
    for el in np.unique(df.case.values):
        d = df[df.case==el]
        ind=[]
        row=d[cols].values
        #print(row)
        indc=[]
        indm=[]
        for r in range(row.shape[0]):
            #print(repr(rowi))
            #print(np.isin(X, row[r]))
            #print(row[r])
            j = np.where( np.isin(X, row[r]).all(axis=1))[0][0]
            #print(j)
            #print(d['choice'].iloc[r])
            indm.append(j)
            indc.append(d['choice'].iloc[r])
                
        IndexMat.append(indm)
        IndCh.append(indc)
    IndexMat=np.vstack(IndexMat)
    ind=np.argsort(IndexMat,axis=1)
    IndCh=np.vstack(IndCh)
    for i in range(ind.shape[0]):
        IndexMat[i,:]=IndexMat[i,ind[i,:]]
        IndCh[i,:]=IndCh[i,ind[i,:]]
    return IndexMat,IndCh

def make_CA_RA(IndexMat,IndCh):
    CA=[]
    RA=[]
    for c in range(IndexMat.shape[0]):
        indr=IndexMat[c,:]
        chrow=IndCh[c,:]
        indn0=np.where(chrow>0)[0]
        ind0=np.where(chrow==0)[0]
        CA.append(indr[indn0].tolist())
        RA.append(indr[ind0].tolist())
        
    return CA,RA

def make_pref_or_choices(IndexMat,IndCh,typeR='pref', drop_duplicates=True):
    if typeR=='pref':
        if drop_duplicates:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh])).drop_duplicates()
        else:
            dfm = pd.DataFrame(np.hstack([IndexMat,IndCh]))
        IndexMat=dfm.iloc[:,0:num].values
        IndCh=dfm.iloc[:,num:].values
        CA,RA0 = make_CA_RA(IndexMat,IndCh)
        CAv=np.vstack(CA)
        RA0 = np.vstack(RA0)
        RA=[]
        for i in range(RA0.shape[1]):
            RA=RA+list(zip(CAv[:,0],RA0[:,i].tolist()))
            
    elif typeR=='choice':
        dfm = pd.DataFrame(np.hstack([IndexMat,IndCh])).groupby(np.arange(num).tolist()).mean().reset_index()
        IndexMat=dfm.iloc[:,0:num].values
        IndCh=dfm.iloc[:,num:].values
        CA,RA = make_CA_RA(IndexMat,IndCh)
    return CA,RA
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv("datasets/ModeCanada.csv",index_col=0)
#df.drop(columns=['income','urban','alt'],inplace=True)
cols_cov=['dist', 'cost', 'ivt', 'ovt', 'freq']
#cols_cov=['dist', 'cost', 'ivt', 'ovt', 'freq','income','urban']
num=3
df = df[(df.noalt==num) & (df.urban==1)]
print(df.shape)
df.head(10)
# Out:
# (1827, 11)
#      case    alt  choice  dist    cost  ivt  ovt  freq  income  urban  noalt
# 696   210  train       0   737  106.65  573   84     2      35      1      3
# 697   210    air       0   737  207.80  181   84     9      35      1      3
# 698   210    car       1   737  140.03  493    0     0      35      1      3
# 699   211  train       1   771  104.65  573   73     2      30      1      3
# 700   211    air       0   771  204.40  181   79     9      30      1      3
# 701   211    car       0   771  146.49  500    0     0      30      1      3
# 702   212  train       1   771  104.65  573   73     2      55      1      3
# 703   212    air       0   771  204.40  181   79     9      55      1      3
# 704   212    car       0   771  146.49  500    0     0      55      1      3
# 705   213  train       0   771  104.65  573   73     2      70      1      3

# %%
#print(df[df.case.isin([ 290,  295,  579,  582, 2981, 2982, 3011, 3012, 3044, 3045])].to_latex(index=False))

# %%
n_splits=1
splitter = GroupShuffleSplit(train_size=0.7, n_splits=n_splits, random_state = 1)
split = splitter.split(df, groups=df['case'])
Res=[]
for cv in range(n_splits):
    print(cv)
    ind_train, ind_test = next(split)
    df_train = df.iloc[ind_train,:].reset_index(drop=True)
    df_test  = df.iloc[ind_test,:].reset_index(drop=True)
    X_tr = np.unique(df_train[cols_cov].values,axis=0)
    X_te = np.unique(df_test[cols_cov].values,axis=0)
    
    #extract choices
    typeR='pref' #'pref'
    #train set
    IndexMat,IndCh=extract_CA_RA(df_train,X_tr,cols_cov)
    CA_tr,RA_tr=make_pref_or_choices(IndexMat,IndCh,typeR=typeR,drop_duplicates=False)
    #test set
    IndexMat,IndCh=extract_CA_RA(df_test,X_te,cols_cov)
    CA_te,RA_te=make_pref_or_choices(IndexMat,IndCh,typeR=typeR,drop_duplicates=True)
    aaa
    #standard scaling
    scalerx=StandardScaler().fit(X_tr)
    X_trasf_tr = scalerx.transform(X_tr)
    X_trasf_te = scalerx.transform(X_te)
    
    # Data dictionary
    data = {}
    data["Pairs"]  = np.hstack([CA_tr,RA_tr])
    data["X"] = X_trasf_tr

    # define kernel and hyperparams
    Kernel = Linear #RBF,Linear

    params={}
    #kernel parameter dictionary
    if Kernel==RBF:
        params={'lengthscale': {'value':1.0*np.ones(data["X"].shape[1],float), 
                                'range':np.vstack([[0.1, 15.0]]*data["X"].shape[1]),
                                'transform': paramz.logexp()},
                     'variance': {'value':np.array([5.0]), 
                                'range':np.vstack([[0.01, 10.0]]),
                                'transform': paramz.logexp()}
                  }
    elif Kernel==Linear:
        params['variance']={'value':0.5+np.random.rand(1,data["X"].shape[1]) ,
                                    'range':np.vstack([[1e-6, 40.0]]*data["X"].shape[1]),
                                    'transform': paramz.logexp()}
    elif Kernel==LinearRBF:
            params={'rbf_lengthscale': {'value':1.0*np.ones(data["X"].shape[1],float), 
                                'range':np.vstack([[0.1, 10.0]]*data["X"].shape[1]),
                                'transform': paramz.logexp()},
                     'rbf_variance': {'value':np.array([1.0]), 
                                'range':np.vstack([[0.01, 10.0]]),
                                'transform': paramz.logexp()},
                    'lin_variance': {'value':1.0*np.ones(data["X"].shape[1],float), 
                                'range':np.vstack([[0.0001, 10.0]]*data["X"].shape[1]),
                                'transform': paramz.logexp()},
                  }

    #define preference model 
    model = erroneousPreference(data,Kernel,params)
    #compute hyperparameters
    model.optimize_hyperparams(num_restarts=1)
    print(model.params)
    
    #sample from posterior
    model.sample(nsamples=1000, tune=100)
    #predicted samples
    predictions = model.predict(X_trasf_te)
    meanu = np.mean(predictions,axis=1)
    Acc = []
    for i in range(len(CA_te)):
        if meanu[CA_te[i]]>np.max(meanu[RA_te[i]]):
            Acc.append(1.0)
        else:
            Acc.append(0.0)
    Res.append(np.mean(Acc))
# Out:
# 0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-184-c785685a030e> in <module>
#      19     IndexMat,IndCh=extract_CA_RA(df_test,X_te,cols_cov)
#      20     CA_te,RA_te=make_pref_or_choices(IndexMat,IndCh,typeR=typeR,drop_duplicates=True)
# ---> 21     aaa
#      22     #standard scaling
#      23     scalerx=StandardScaler().fit(X_tr)
#
# NameError: name 'aaa' is not defined

# %%
RA_tr
# Out:
# [([474], 475),
#  ([474], 475),
#  ([476], 474),
#  ([476], 474),
#  ([476], 474),
#  ([475], 474),
#  ([485], 483),
#  ([480], 481),
#  ([482], 480),
#  ([482], 480),
#  ([481], 480),
#  ([470], 468),
#  ([479], 477),
#  ([435], 436),
#  ([466], 465),
#  ([101], 102),
#  ([101], 102),
#  ([101], 102),
#  ([416], 414),
#  ([14], 13),
#  ([110], 108),
#  ([110], 108),
#  ([110], 108),
#  ([95], 94),
#  ([95], 94),
#  ([95], 94),
#  ([105], 104),
#  ([110], 107),
#  ([110], 107),
#  ([294], 292),
#  ([294], 292),
#  ([413], 411),
#  ([413], 411),
#  ([407], 405),
#  ([410], 408),
#  ([409], 408),
#  ([409], 408),
#  ([116], 114),
#  ([116], 114),
#  ([142], 141),
#  ([142], 141),
#  ([121], 120),
#  ([130], 129),
#  ([130], 129),
#  ([136], 135),
#  ([431], 426),
#  ([165], 163),
#  ([168], 166),
#  ([386], 384),
#  ([386], 384),
#  ([463], 462),
#  ([461], 459),
#  ([458], 456),
#  ([458], 456),
#  ([458], 456),
#  ([458], 456),
#  ([453], 454),
#  ([455], 453),
#  ([434], 432),
#  ([68], 69),
#  ([35], 34),
#  ([35], 34),
#  ([35], 34),
#  ([35], 34),
#  ([35], 34),
#  ([34], 35),
#  ([34], 35),
#  ([59], 60),
#  ([68], 69),
#  ([68], 69),
#  ([279], 277),
#  ([278], 277),
#  ([290], 289),
#  ([90], 91),
#  ([63], 65),
#  ([307], 308),
#  ([430], 427),
#  ([300], 298),
#  ([300], 298),
#  ([51], 50),
#  ([51], 50),
#  ([51], 50),
#  ([51], 50),
#  ([51], 50),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([26], 25),
#  ([38], 37),
#  ([38], 37),
#  ([38], 37),
#  ([51], 49),
#  ([268], 269),
#  ([268], 269),
#  ([270], 268),
#  ([270], 268),
#  ([270], 268),
#  ([270], 268),
#  ([270], 268),
#  ([270], 268),
#  ([269], 268),
#  ([269], 268),
#  ([398], 396),
#  ([391], 390),
#  ([64], 62),
#  ([32], 31),
#  ([32], 31),
#  ([32], 31),
#  ([32], 31),
#  ([32], 31),
#  ([41], 40),
#  ([56], 53),
#  ([56], 53),
#  ([56], 53),
#  ([56], 53),
#  ([276], 274),
#  ([276], 274),
#  ([276], 274),
#  ([276], 274),
#  ([276], 274),
#  ([287], 286),
#  ([401], 399),
#  ([387], 388),
#  ([86], 85),
#  ([86], 85),
#  ([86], 85),
#  ([86], 85),
#  ([86], 85),
#  ([55], 54),
#  ([55], 54),
#  ([55], 54),
#  ([78], 76),
#  ([78], 76),
#  ([86], 84),
#  ([86], 84),
#  ([285], 283),
#  ([285], 283),
#  ([285], 283),
#  ([285], 283),
#  ([285], 283),
#  ([404], 402),
#  ([251], 253),
#  ([251], 253),
#  ([251], 253),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([254], 251),
#  ([253], 251),
#  ([380], 378),
#  ([380], 378),
#  ([357], 355),
#  ([366], 367),
#  ([306], 304),
#  ([305], 304),
#  ([10], 9),
#  ([246], 244),
#  ([264], 262),
#  ([374], 372),
#  ([5], 3),
#  ([3], 4),
#  ([4], 3),
#  ([4], 3),
#  ([4], 3),
#  ([213], 211),
#  ([232], 233),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([234], 232),
#  ([247], 248),
#  ([350], 349),
#  ([335], 336),
#  ([335], 336),
#  ([337], 335),
#  ([259], 257),
#  ([348], 346),
#  ([341], 338),
#  ([341], 338),
#  ([341], 338),
#  ([341], 338),
#  ([341], 338),
#  ([341], 338),
#  ([341], 338),
#  ([328], 326),
#  ([328], 326),
#  ([334], 332),
#  ([342], 339),
#  ([371], 369),
#  ([371], 369),
#  ([345], 343),
#  ([345], 343),
#  ([344], 343),
#  ([344], 343),
#  ([359], 360),
#  ([361], 359),
#  ([362], 358),
#  ([362], 358),
#  ([362], 358),
#  ([375], 376),
#  ([377], 375),
#  ([377], 375),
#  ([354], 352),
#  ([353], 352),
#  ([365], 363),
#  ([310], 312),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([313], 310),
#  ([312], 310),
#  ([312], 310),
#  ([312], 310),
#  ([322], 320),
#  ([322], 320),
#  ([322], 320),
#  ([322], 320),
#  ([322], 320),
#  ([99], 98),
#  ([99], 98),
#  ([99], 98),
#  ([149], 148),
#  ([149], 148),
#  ([231], 229),
#  ([261], 256),
#  ([7], 6),
#  ([74], 72),
#  ([74], 72),
#  ([73], 72),
#  ([133], 132),
#  ([219], 217),
#  ([219], 217),
#  ([238], 239),
#  ([240], 238),
#  ([418], 417),
#  ([423], 424),
#  ([420], 421),
#  ([1], 0),
#  ([89], 88),
#  ([89], 88),
#  ([145], 144),
#  ([228], 226),
#  ([228], 226),
#  ([441], 442),
#  ([15], 12),
#  ([99], 97),
#  ([99], 97),
#  ([99], 97),
#  ([99], 97),
#  ([99], 97),
#  ([149], 147),
#  ([446], 444),
#  ([314], 311),
#  ([314], 311),
#  ([318], 316),
#  ([318], 316),
#  ([318], 316),
#  ([318], 316),
#  ([318], 316),
#  ([318], 316),
#  ([319], 315),
#  ([325], 323),
#  ([325], 323),
#  ([331], 329),
#  ([273], 271),
#  ([242], 241),
#  ([255], 250),
#  ([302], 301),
#  ([296], 295),
#  ([473], 471),
#  ([440], 438),
#  ([222], 220),
#  ([267], 265),
#  ([267], 265),
#  ([267], 265),
#  ([395], 393),
#  ([383], 381),
#  ([216], 214),
#  ([449], 447),
#  ([452], 450),
#  ([237], 235),
#  ([282], 280),
#  ([188], 187),
#  ([188], 187),
#  ([189], 187),
#  ([191], 190),
#  ([183], 181),
#  ([185], 184),
#  ([139], 138),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([159], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([158], 157),
#  ([161], 160),
#  ([198], 196),
#  ([198], 196),
#  ([200], 199),
#  ([201], 199),
#  ([201], 199),
#  ([201], 199),
#  ([47], 43),
#  ([79], 75),
#  ([176], 175),
#  ([176], 175),
#  ([176], 175),
#  ([176], 175),
#  ([169], 170),
#  ([111], 109),
#  ([46], 44),
#  ([46], 44),
#  ([46], 44),
#  ([46], 44),
#  ([46], 44),
#  ([80], 77),
#  ([177], 178),
#  ([171], 172),
#  ([203], 202),
#  ([207], 205),
#  ([225], 223),
#  ([224], 223),
#  ([209], 208),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([123], 124),
#  ([194], 193),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([154], 155),
#  ([151], 152),
#  ([151], 152),
#  ([151], 152),
#  ([151], 152),
#  ([151], 152),
#  ([118], 115),
#  ([127], 126),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 19),
#  ([18], 21),
#  ([18], 21),
#  ([18], 20),
#  ([18], 20),
#  ([28], 29),
#  ([28], 29),
#  ([28], 29),
#  ([28], 29),
#  ([28], 29),
#  ([474], 476),
#  ([474], 476),
#  ([476], 475),
#  ([476], 475),
#  ([476], 475),
#  ([475], 476),
#  ([485], 484),
#  ([480], 482),
#  ([482], 481),
#  ([482], 481),
#  ([481], 482),
#  ([470], 469),
#  ([479], 478),
#  ([435], 437),
#  ([466], 467),
#  ([101], 103),
#  ([101], 103),
#  ([101], 103),
#  ([416], 415),
#  ([14], 17),
#  ([110], 112),
#  ([110], 112),
#  ([110], 112),
#  ([95], 96),
#  ([95], 96),
#  ([95], 96),
#  ([105], 106),
#  ([110], 112),
#  ([110], 112),
#  ([294], 293),
#  ([294], 293),
#  ([413], 412),
#  ([413], 412),
#  ([407], 406),
#  ([410], 409),
#  ([409], 410),
#  ([409], 410),
#  ([116], 119),
#  ([116], 119),
#  ([142], 143),
#  ([142], 143),
#  ([121], 122),
#  ([130], 131),
#  ([130], 131),
#  ([136], 137),
#  ([431], 428),
#  ([165], 164),
#  ([168], 167),
#  ([386], 385),
#  ([386], 385),
#  ([463], 464),
#  ([461], 460),
#  ([458], 457),
#  ([458], 457),
#  ([458], 457),
#  ([458], 457),
#  ([453], 455),
#  ([455], 454),
#  ([434], 433),
#  ([68], 71),
#  ([35], 36),
#  ([35], 36),
#  ([35], 36),
#  ([35], 36),
#  ([35], 36),
#  ([34], 36),
#  ([34], 36),
#  ([59], 61),
#  ([68], 70),
#  ([68], 70),
#  ([279], 278),
#  ([278], 279),
#  ([290], 291),
#  ([90], 93),
#  ([63], 67),
#  ([307], 309),
#  ([430], 429),
#  ([300], 299),
#  ([300], 299),
#  ([51], 52),
#  ([51], 52),
#  ([51], 52),
#  ([51], 52),
#  ([51], 52),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([26], 27),
#  ([38], 39),
#  ([38], 39),
#  ([38], 39),
#  ([51], 52),
#  ([268], 270),
#  ([268], 270),
#  ([270], 269),
#  ([270], 269),
#  ([270], 269),
#  ([270], 269),
#  ([270], 269),
#  ([270], 269),
#  ([269], 270),
#  ([269], 270),
#  ([398], 397),
#  ([391], 392),
#  ([64], 66),
#  ([32], 33),
#  ([32], 33),
#  ([32], 33),
#  ([32], 33),
#  ([32], 33),
#  ([41], 42),
#  ([56], 58),
#  ([56], 58),
#  ([56], 58),
#  ([56], 58),
#  ([276], 275),
#  ([276], 275),
#  ([276], 275),
#  ([276], 275),
#  ([276], 275),
#  ([287], 288),
#  ([401], 400),
#  ([387], 389),
#  ([86], 87),
#  ([86], 87),
#  ([86], 87),
#  ([86], 87),
#  ([86], 87),
#  ([55], 57),
#  ([55], 57),
#  ([55], 57),
#  ([78], 81),
#  ([78], 81),
#  ([86], 87),
#  ([86], 87),
#  ([285], 284),
#  ([285], 284),
#  ([285], 284),
#  ([285], 284),
#  ([285], 284),
#  ([404], 403),
#  ([251], 254),
#  ([251], 254),
#  ([251], 254),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([254], 253),
#  ([253], 254),
#  ([380], 379),
#  ([380], 379),
#  ([357], 356),
#  ([366], 368),
#  ([306], 305),
#  ([305], 306),
#  ([10], 11),
#  ([246], 245),
#  ([264], 263),
#  ([374], 373),
#  ([5], 4),
#  ([3], 5),
#  ([4], 5),
#  ([4], 5),
#  ([4], 5),
#  ([213], 212),
#  ([232], 234),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([234], 233),
#  ([247], 249),
#  ([350], 351),
#  ([335], 337),
#  ([335], 337),
#  ([337], 336),
#  ([259], 260),
#  ([348], 347),
#  ([341], 340),
#  ([341], 340),
#  ([341], 340),
#  ([341], 340),
#  ([341], 340),
#  ([341], 340),
#  ([341], 340),
#  ([328], 327),
#  ([328], 327),
#  ([334], 333),
#  ([342], 340),
#  ([371], 370),
#  ([371], 370),
#  ([345], 344),
#  ([345], 344),
#  ([344], 345),
#  ([344], 345),
#  ([359], 361),
#  ([361], 360),
#  ([362], 360),
#  ([362], 360),
#  ([362], 360),
#  ([375], 377),
#  ([377], 376),
#  ([377], 376),
#  ([354], 353),
#  ([353], 354),
#  ([365], 364),
#  ([310], 313),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([313], 312),
#  ([312], 313),
#  ([312], 313),
#  ([312], 313),
#  ([322], 321),
#  ([322], 321),
#  ([322], 321),
#  ([322], 321),
#  ([322], 321),
#  ([99], 100),
#  ([99], 100),
#  ([99], 100),
#  ([149], 150),
#  ([149], 150),
#  ([231], 230),
#  ([261], 258),
#  ([7], 8),
#  ([74], 73),
#  ([74], 73),
#  ([73], 74),
#  ([133], 134),
#  ([219], 218),
#  ([219], 218),
#  ([238], 240),
#  ([240], 239),
#  ([418], 419),
#  ([423], 425),
#  ([420], 422),
#  ([1], 2),
#  ([89], 92),
#  ([89], 92),
#  ([145], 146),
#  ([228], 227),
#  ([228], 227),
#  ([441], 443),
#  ([15], 16),
#  ([99], 100),
#  ([99], 100),
#  ([99], 100),
#  ([99], 100),
#  ([99], 100),
#  ([149], 150),
#  ([446], 445),
#  ([314], 312),
#  ([314], 312),
#  ([318], 317),
#  ([318], 317),
#  ([318], 317),
#  ([318], 317),
#  ([318], 317),
#  ([318], 317),
#  ([319], 317),
#  ([325], 324),
#  ([325], 324),
#  ([331], 330),
#  ([273], 272),
#  ([242], 243),
#  ([255], 252),
#  ([302], 303),
#  ([296], 297),
#  ([473], 472),
#  ([440], 439),
#  ([222], 221),
#  ([267], 266),
#  ([267], 266),
#  ([267], 266),
#  ([395], 394),
#  ([383], 382),
#  ([216], 215),
#  ([449], 448),
#  ([452], 451),
#  ([237], 236),
#  ([282], 281),
#  ([188], 189),
#  ([188], 189),
#  ([189], 188),
#  ([191], 192),
#  ([183], 182),
#  ([185], 186),
#  ([139], 140),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([159], 158),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([158], 159),
#  ([161], 162),
#  ([198], 197),
#  ([198], 197),
#  ([200], 201),
#  ([201], 200),
#  ([201], 200),
#  ([201], 200),
#  ([47], 45),
#  ([79], 82),
#  ([176], 180),
#  ([176], 180),
#  ([176], 180),
#  ([176], 180),
#  ([169], 174),
#  ([111], 113),
#  ([46], 48),
#  ([46], 48),
#  ([46], 48),
#  ([46], 48),
#  ([46], 48),
#  ([80], 83),
#  ([177], 179),
#  ([171], 173),
#  ([203], 204),
#  ([207], 206),
#  ([225], 224),
#  ([224], 225),
#  ([209], 210),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([123], 125),
#  ([194], 195),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([154], 156),
#  ([151], 153),
#  ([151], 153),
#  ([151], 153),
#  ([151], 153),
#  ([151], 153),
#  ([118], 117),
#  ([127], 128),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 22),
#  ([18], 23),
#  ([18], 23),
#  ([18], 24),
#  ([18], 24),
#  ([28], 30),
#  ([28], 30),
#  ([28], 30),
#  ([28], 30),
#  ([28], 30)]

# %%
Iteration 0  -50.42106060466172

  0%|          | 0/1100 [00:00<?, ?it/s]

{'lengthscale': {'value': array([ 2.33749038, 15.        , 15.        ,  1.1499474 , 15.        ]), 'range': array([[ 0.1, 15. ],
       [ 0.1, 15. ],
       [ 0.1, 15. ],
       [ 0.1, 15. ],
       [ 0.1, 15. ]]), 'transform': <utility.paramz.logexp object at 0x7fc4245e6f10>}, 'variance': {'value': array([9.48633639]), 'range': array([[ 0.01, 10.  ]]), 'transform': <utility.paramz.logexp object at 0x7fc4245e6ca0>}}

100%|██████████| 1100/1100 [00:18<00:00, 58.25it/s]

# %%
np.mean(Res)
# Out:
# 0.9233245498462891

# %%
#Linear mean: 0.9041326306543697
[0.8636363636363636,
 0.8571428571428571,
 1.0,
 0.9,
 0.9,
 0.9130434782608695,
 0.8571428571428571,
 0.9090909090909091,
 0.9523809523809523,
 0.8888888888888888]
# Out:
# [0.8636363636363636,
#  0.8571428571428571,
#  1.0,
#  0.9,
#  0.9,
#  0.9130434782608695,
#  0.8571428571428571,
#  0.9090909090909091,
#  0.9523809523809523,
#  0.8888888888888888]

# %%
#RBF mean: 0.9233
[0.9090909090909091,
 0.8571428571428571,
 1.0,
 0.9,
 0.9,
 0.9130434782608695,
 0.8571428571428571,
 1.0,
 0.9523809523809523,
 0.9444444444444444]
# Out:
# [0.9090909090909091,
#  0.8571428571428571,
#  1.0,
#  0.9,
#  0.9,
#  0.9130434782608695,
#  0.8571428571428571,
#  1.0,
#  0.9523809523809523,
#  0.9444444444444444]

# %%
#sample from posterior
model.sample(nsamples=1000, tune=100)
#predicted samples
predictions = model.predict(X_trasf_te)
# Out:
# 100%|██████████| 1100/1100 [00:09<00:00, 113.04it/s]

# %%
# Out:
# 0.8269230769230769

# %%
0.94117
# Out:
# array([0.25819412])

# %%
meanu[RA_te[0]]
# Out:
# array([-0.50857248])

# %%
from scipy.stats import norm
mean=meanu[CA_te[0],0]
std_dev=np.sqrt(Sigmau[CA_te[0],CA_te[0]])
mean1=meanu[RA_te[0],0]
std_dev1=np.sqrt(Sigmau[RA_te[0],RA_te[0]])
xx = np.linspace(mean - 7*std_dev, mean + 4*std_dev, 1000)
# Calculate the corresponding y-axis values using the Gaussian PDF formula
yy = norm.pdf(xx, mean, std_dev)
yy1 = norm.pdf(xx, mean1, std_dev1)
# Plot the Gaussian PDF
plt.plot(xx, yy,color='C0',label="p(u$_1$)")
plt.plot(xx, yy1[:,0],color='C1',label="p(u$_2$)")
plt.plot(xx, yy1[:,1],color='C2',label="p(u$_3$)")
plt.xlabel('u',fontsize=16)
#plt.ylabel('Probability Density')
plt.legend(fontsize=16)
plt.grid(True)
plt.show()
#plt.savefig("modecanada_choice3.pdf")
# Out:
# [array([145, 409]),
#  array([ 474, 1025]),
#  array([ 553, 1008]),
#  array([ 561, 1008]),
#  array([ 568, 1056]),
#  array([143, 411]),
#  array([136, 341]),
#  array([136, 377]),
#  array([143, 380]),
#  array([144, 421]),
#  array([ 434, 1000]),
#  array([ 452, 1005]),
#  array([ 483, 1004]),
#  array([ 435, 1004]),
#  array([ 453, 1005]),
#  array([467, 992]),
#  array([518, 948]),
#  array([527, 961]),
#  array([527, 961]),
#  array([502, 958]),
#  array([513, 531]),
#  array([513, 946]),
#  array([521, 947]),
#  array([577, 973]),
#  array([546, 956]),
#  array([576, 962]),
#  array([ 685, 1076]),
#  array([ 828, 1061]),
#  array([716, 828]),
#  array([ 805, 1166]),
#  array([ 952, 1161]),
#  array([800, 952]),
#  array([ 800, 1161]),
#  array([1043, 1186]),
#  array([ 817, 1043]),
#  array([ 817, 1186]),
#  array([ 563, 1021]),
#  array([171, 420]),
#  array([161, 383]),
#  array([ 448, 1001]),
#  array([ 795, 1179]),
#  array([ 933, 1168]),
#  array([808, 941]),
#  array([176, 425]),
#  array([ 567, 1022]),
#  array([146, 168]),
#  array([168, 393]),
#  array([175, 399]),
#  array([ 449, 1019]),
#  array([516, 970]),
#  array([447, 944]),
#  array([488, 960]),
#  array([355, 964]),
#  array([356, 966]),
#  array([443, 918]),
#  array([417, 917]),
#  array([535, 953]),
#  array([473, 953]),
#  array([768, 884]),
#  array([746, 889]),
#  array([ 825, 1034]),
#  array([815, 971]),
#  array([811, 971]),
#  array([789, 967]),
#  array([428, 984]),
#  array([476, 945]),
#  array([ 781, 1185]),
#  array([ 883, 1176]),
#  array([413, 926]),
#  array([ 739, 1153]),
#  array([754, 925]),
#  array([271, 928]),
#  array([278, 407]),
#  array([ 540, 1013]),
#  array([ 675, 1060]),
#  array([708, 867]),
#  array([ 56, 408]),
#  array([ 57, 336]),
#  array([ 76, 323]),
#  array([694, 797]),
#  array([ 49, 378]),
#  array([ 61, 335]),
#  array([ 41, 319]),
#  array([ 79, 332]),
#  array([ 40, 342]),
#  array([ 43, 335]),
#  array([ 31, 344]),
#  array([ 32, 354]),
#  array([564, 990]),
#  array([670, 784]),
#  array([700, 866]),
#  array([711, 862]),
#  array([ 698, 1151]),
#  array([ 77, 349]),
#  array([ 76, 371]),
#  array([713, 877]),
#  array([ 81, 397]),
#  array([ 63, 442]),
#  array([ 66, 369]),
#  array([ 83, 353]),
#  array([ 80, 340]),
#  array([ 64, 352]),
#  array([ 88, 347]),
#  array([ 78, 357]),
#  array([ 65, 361]),
#  array([ 67, 368]),
#  array([707, 878]),
#  array([379, 900]),
#  array([424, 927]),
#  array([107, 378]),
#  array([ 91, 427]),
#  array([103, 319]),
#  array([100, 342]),
#  array([106, 335]),
#  array([686, 975]),
#  array([670, 853]),
#  array([700, 929]),
#  array([ 700, 1100]),
#  array([338, 934]),
#  array([741, 920]),
#  array([1075, 1189]),
#  array([204, 904]),
#  array([233, 908]),
#  array([205, 907]),
#  array([217, 890]),
#  array([234, 908]),
#  array([197, 898]),
#  array([261, 898]),
#  array([266, 309]),
#  array([412, 871]),
#  array([431, 871]),
#  array([506, 908]),
#  array([486, 928]),
#  array([ 558, 1011]),
#  array([ 570, 1010]),
#  array([ 528, 1010]),
#  array([ 690, 1010]),
#  array([550, 658]),
#  array([550, 991]),
#  array([ 706, 1009]),
#  array([732, 782]),
#  array([ 732, 1042]),
#  array([ 775, 1150]),
#  array([ 911, 1130]),
#  array([718, 911]),
#  array([ 909, 1160]),
#  array([778, 942]),
#  array([1074, 1188]),
#  array([ 852, 1141]),
#  array([244, 916]),
#  array([318, 924]),
#  array([468, 897]),
#  array([487, 910]),
#  array([765, 879]),
#  array([793, 903]),
#  array([189, 403]),
#  array([238, 406]),
#  array([115, 401]),
#  array([209, 401]),
#  array([245, 400]),
#  array([238, 402]),
#  array([253, 391]),
#  array([272, 437]),
#  array([273, 392]),
#  array([ 552, 1002]),
#  array([ 648, 1063]),
#  array([611, 769]),
#  array([ 625, 1041]),
#  array([743, 873]),
#  array([ 507, 1036]),
#  array([ 578, 1018]),
#  array([ 585, 1035]),
#  array([ 802, 1049]),
#  array([804, 985]),
#  array([358, 881]),
#  array([744, 791]),
#  array([ 801, 1171]),
#  array([ 58, 308]),
#  array([ 33, 190]),
#  array([ 68, 240]),
#  array([ 50, 210]),
#  array([ 44, 247]),
#  array([ 53, 240]),
#  array([ 37, 277]),
#  array([ 444, 1006]),
#  array([543, 988]),
#  array([519, 988]),
#  array([618, 759]),
#  array([ 618, 1037]),
#  array([681, 856]),
#  array([ 688, 1145]),
#  array([ 857, 1143]),
#  array([ 59, 320]),
#  array([ 69, 257]),
#  array([ 51, 222]),
#  array([ 34, 256]),
#  array([ 45, 264]),
#  array([120, 287]),
#  array([ 560, 1044]),
#  array([657, 809]),
#  array([627, 767]),
#  array([ 627, 1015]),
#  array([ 643, 1017]),
#  array([692, 858]),
#  array([ 854, 1099]),
#  array([ 60, 331]),
#  array([ 70, 276]),
#  array([ 52, 242]),
#  array([ 46, 281]),
#  array([ 54, 276]),
#  array([ 36, 288]),
#  array([121, 301]),
#  array([ 35, 286]),
#  array([ 38, 302]),
#  array([530, 989]),
#  array([ 663, 1070]),
#  array([636, 774]),
#  array([701, 859]),
#  array([717, 860]),
#  array([ 28, 291]),
#  array([514, 972]),
#  array([529, 994]),
#  array([548, 644]),
#  array([620, 704]),
#  array([ 749, 1026]),
#  array([593, 749]),
#  array([ 593, 1026]),
#  array([705, 850]),
#  array([ 705, 1096]),
#  array([697, 839]),
#  array([ 844, 1136]),
#  array([624, 794]),
#  array([ 624, 1038]),
#  array([  8, 294]),
#  array([  1, 293]),
#  array([646, 742]),
#  array([654, 755]),
#  array([691, 847]),
#  array([ 90, 295]),
#  array([ 10, 295]),
#  array([ 11, 215]),
#  array([ 6, 25]),
#  array([ 25, 195]),
#  array([  6, 195]),
#  array([  3, 249]),
#  array([  2, 248]),
#  array([426, 951]),
#  array([536, 951]),
#  array([ 587, 1031]),
#  array([621, 689]),
#  array([617, 696]),
#  array([729, 969]),
#  array([596, 729]),
#  array([745, 976]),
#  array([635, 780]),
#  array([727, 832]),
#  array([623, 837]),
#  array([ 827, 1066]),
#  array([684, 827]),
#  array([672, 833]),
#  array([ 655, 1110]),
#  array([646, 996]),
#  array([ 679, 1118]),
#  array([640, 835]),
#  array([533, 959]),
#  array([522, 959]),
#  array([604, 830]),
#  array([628, 821]),
#  array([632, 830]),
#  array([649, 865]),
#  array([480, 949]),
#  array([664, 839]),
#  array([659, 846]),
#  array([652, 846]),
#  array([581, 846]),
#  array([605, 834]),
#  array([ 605, 1064]),
#  array([ 840, 1069]),
#  array([598, 840]),
#  array([579, 840]),
#  array([ 637, 1108]),
#  array([629, 875]),
#  array([ 829, 1140]),
#  array([494, 950]),
#  array([ 622, 1030]),
#  array([ 511, 1014]),
#  array([ 680, 1106]),
#  array([ 848, 1054]),
#  array([592, 848]),
#  array([619, 838]),
#  array([591, 842]),
#  array([ 591, 1089]),
#  array([610, 842]),
#  array([ 22, 328]),
#  array([139, 337]),
#  array([ 806, 1046]),
#  array([589, 806]),
#  array([ 589, 1046]),
#  array([609, 763]),
#  array([ 880, 1092]),
#  array([ 902, 1093]),
#  array([674, 894]),
#  array([ 12, 370]),
#  array([597, 813]),
#  array([777, 891]),
#  array([ 783, 1007]),
#  array([ 24, 268]),
#  array([141, 285]),
#  array([586, 799]),
#  array([ 586, 1080]),
#  array([634, 726]),
#  array([660, 895]),
#  array([  7, 199]),
#  array([ 19, 150]),
#  array([ 19, 235]),
#  array([132, 252]),
#  array([ 787, 1094]),
#  array([575, 787]),
#  array([ 575, 1094]),
#  array([615, 715]),
#  array([584, 737]),
#  array([651, 888]),
#  array([ 614, 1147]),
#  array([ 872, 1107]),
#  array([  5, 212]),
#  array([ 18, 280]),
#  array([ 798, 1082]),
#  array([588, 798]),
#  array([ 588, 1082]),
#  array([639, 722]),
#  array([  9, 225]),
#  array([ 20, 268]),
#  array([134, 285]),
#  array([586, 799]),
#  array([599, 751]),
#  array([731, 977]),
#  array([ 14, 284]),
#  array([600, 810]),
#  array([730, 882]),
#  array([747, 999]),
#  array([ 13, 283]),
#  array([668, 906]),
#  array([ 16, 297]),
#  array([601, 816]),
#  array([602, 822]),
#  array([ 15, 296]),
#  array([122, 305]),
#  array([600, 762]),
#  array([ 600, 1071]),
#  array([372, 963]),
#  array([ 753, 1072]),
#  array([ 606, 1083]),
#  array([580, 748]),
#  array([ 807, 1128]),
#  array([375, 974]),
#  array([ 489, 1044]),
#  array([662, 740]),
#  array([653, 740]),
#  array([ 735, 1129]),
#  array([723, 728]),
#  array([682, 785]),
#  array([ 594, 1072]),
#  array([ 612, 1121]),
#  array([501, 935]),
#  array([ 761, 1078]),
#  array([771, 885]),
#  array([766, 861]),
#  array([757, 943]),
#  array([638, 812]),
#  array([650, 818]),
#  array([656, 886]),
#  array([ 796, 1047]),
#  array([458, 974]),
#  array([542, 965]),
#  array([503, 965]),
#  array([616, 719]),
#  array([595, 758]),
#  array([ 595, 1015]),
#  array([677, 851]),
#  array([ 849, 1180]),
#  array([ 626, 1023]),
#  array([608, 788]),
#  array([645, 932]),
#  array([667, 868]),
#  array([695, 870]),
#  array([515, 642]),
#  array([630, 702]),
#  array([720, 905]),
#  array([673, 905]),
#  array([693, 896]),
#  array([676, 901]),
#  array([ 824, 1058]),
#  array([ 826, 1059]),
#  array([ 734, 1149]),
#  array([590, 687]),
#  array([683, 790]),
#  array([ 482, 1027]),
#  array([ 574, 1087]),
#  array([699, 733]),
#  array([ 699, 1133]),
#  array([ 493, 1057]),
#  array([703, 772]),
#  array([712, 758]),
#  array([714, 773]),
#  array([ 55, 339]),
#  array([ 26, 270]),
#  array([267, 455]),
#  array([267, 440]),
#  array([ 23, 230]),
#  array([ 39, 279]),
#  array([262, 429]),
#  array([258, 446]),
#  array([154, 384]),
#  array([116, 389]),
#  array([140, 325]),
#  array([325, 373]),
#  array([140, 373]),
#  array([133, 388]),
#  array([177, 485]),
#  array([174, 498]),
#  array([174, 433]),
#  array([179, 504]),
#  array([179, 416]),
#  array([188, 569]),
#  array([188, 457]),
#  array([187, 492]),
#  array([194, 466]),
#  array([ 42, 128]),
#  array([ 42, 274]),
#  array([351, 887]),
#  array([364, 921]),
#  array([387, 940]),
#  array([ 74, 461]),
#  array([ 86, 438]),
#  array([ 84, 456]),
#  array([ 73, 148]),
#  array([478, 874]),
#  array([398, 940]),
#  array([477, 899]),
#  array([497, 537]),
#  array([497, 893]),
#  array([517, 721]),
#  array([517, 986]),
#  array([439, 892]),
#  array([520, 914]),
#  array([479, 912]),
#  array([523, 915]),
#  array([ 539, 1016]),
#  array([484, 913]),
#  array([ 98, 329]),
#  array([ 96, 326]),
#  array([ 97, 306]),
#  array([314, 939]),
#  array([333, 938]),
#  array([359, 937]),
#  array([327, 936]),
#  array([ 94, 228]),
#  array([104, 218]),
#  array([102, 232]),
#  array([101, 196]),
#  array([114, 250]),
#  array([113, 206]),
#  array([112, 214]),
#  array([126, 239]),
#  array([135, 219]),
#  array([ 92, 246]),
#  array([ 99, 298]),
#  array([ 98, 254]),
#  array([310, 957]),
#  array([311, 981]),
#  array([322, 979]),
#  array([ 99, 255]),
#  array([119, 307]),
#  array([251, 955]),
#  array([316, 983]),
#  array([374, 982]),
#  array([481, 954]),
#  array([508, 980]),
#  array([118, 275]),
#  array([117, 330]),
#  array([532, 978])]

# %%
len(CA_tr)
# Out:
# 378

# %%
X_trasf_tr.shape
# Out:
# (964, 5)

# %% [markdown]
# # Choices

# %%
dimA = num
#choice data
data={'X': X_trasf_tr,#objects
      'CA': CA_tr,#choiced objects
      'RA': RA_tr,#rejected objects
      'dimA':dimA# dimension of the choice set
          }

# number of latent utilities
latent_dim=2

# define kernel 
Kernel = jaxrbf.RBF
#hyperparameters of the kernel
params = {'lengthscale_0': {'value':0.8*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 5.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_0': {'value':np.array([1.0]), 
                            'range':np.vstack([[0.05, 50.0]]),
                            'transform': paramz.logexp()},
            'lengthscale_1': {'value':0.8*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 5.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_1': {'value':np.array([1.0]), 
                            'range':np.vstack([[0.05, 50.0]]),
                            'transform': paramz.logexp()}
              }



# define choice model 
model = erroneousChoice(data,Kernel,params,latent_dim,jitter=1e-6,typeR="pseudo")
# compute variational inference and estimate hyperparameters
model.optimize_hyperparams(niterations=5000,kernel_hypers_fixed=False, 
                           #init_f=np.zeros(2*X.shape[0]),
                           diagonal=False)
print(model.params)
# Out:
# /home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py:62: RuntimeWarning: invalid value encountered in matmul
#   IKxx = L_inv@L_inv.T
# 899250.9245934262
#  lower bound 924.9109901742497:   4%|▎         | 183/5000 [55:23<24:17:57, 18.16s/it]
#  lower bound 1453.7011551774797:   0%|          | 25/5000 [26:55<89:18:01, 64.62s/it]
#   0%|          | 0/5000 [00:00<?, ?it/s]
# 523.3407424737136
#  lower bound 3200387.472693111:   3%|▎         | 172/5000 [10:34<5:17:00,  3.94s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-138-06f1f6b7eb1a> in <module>
#      32 model = erroneousChoice(data,Kernel,params,latent_dim,jitter=1e-6,typeR="pseudo")
#      33 # compute variational inference and estimate hyperparameters
# ---> 34 model.optimize_hyperparams(niterations=5000,kernel_hypers_fixed=False,
#      35                            #init_f=np.zeros(2*X.shape[0]),
#      36                            diagonal=False)
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/abstractModel.py in optimize_hyperparams(self, num_restarts, niterations, kernel_hypers_fixed, init_f, diagonal)
#      45                                           self.params,
#      46                                           self._log_likelihood)
# ---> 47             infer.optimize(niterations,
#      48                            kernel_hypers_fixed=kernel_hypers_fixed,
#      49                            init_f=init_f,diagonal=diagonal)
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py in optimize(self, niterations, progress, kernel_hypers_fixed, init_f, diagonal)
#     260
#     261         loglike =self._log_like()
# --> 262         f, Sigma, log_kernel_hypers, advi_params = self.advi(niterations,loglike,
#     263                                                              init_params_kernel,
#     264                                                              kernel_hypers_fixed=kernel_hypers_fixed,
#
# ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py in advi(self, niterations, loglike, init_params_kernel, progress, kernel_hypers_fixed, diagonal, init_f)
#     217
#     218             if t<int(0.1*niterations):
# --> 219                  opt_state = update_start(t, opt_state)
#     220             else:
#     221                 opt_state = update(t, opt_state)
#
# ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/example_libraries/optimizers.py in <lambda>(data, xs)
#     118     OptimizerState,
#     119     lambda xs: ((xs.packed_state,), (xs.tree_def, xs.subtree_defs)),
# --> 120     lambda data, xs: OptimizerState(xs[0], data[0], data[1]))  # type: ignore[index]
#     121
#     122
#
# KeyboardInterrupt:

# %%
import jax
? jax.numpy.linalg.solve

# %%
np.tril_indices(3)
# Out:
# (array([0, 1, 1, 2, 2, 2]), array([0, 0, 1, 0, 1, 2]))

# %%
Accuracy=0.7855297157622739

{'lengthscale_0': {'value': array([0.19070994, 0.08555967, 0.07452685, 0.32012958, 0.37082475]), 'range': array([[0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ]]), 'transform': <utility.paramz.logexp object at 0x7f0d75618e80>}, 'variance_0': {'value': array([2.15207161]), 'range': array([[ 0.05, 50.  ]]), 'transform': <utility.paramz.logexp object at 0x7f0d75618eb0>}, 'lengthscale_1': {'value': array([0.17421087, 0.06796804, 0.02839068, 0.26718789, 0.34512444]), 'range': array([[0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ],
       [0.1, 5. ]]), 'transform': <utility.paramz.logexp object at 0x7f0d5d3b0040>}, 'variance_1': {'value': array([2.06409303]), 'range': array([[ 0.05, 50.  ]]), 'transform': <utility.paramz.logexp object at 0x7f0d5d3b00d0>}}

# %%
import pickle

a = {'hello': 'world'}

with open('ModeCanada_choice3_latet_full', 'wb') as handle:
    pickle.dump(model.meanVI, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
predictions = model.predict_VI(X_trasf_te)

meanu=predictions[0]
Sigmau=predictions[1]

# %%
Acc = []
for i in range(len(CA_te)):
    if meanu[CA_te[i],:]>np.max(meanu[RA_te[i],:]):
        Acc.append(1.0)
    else:
        Acc.append(0.0)
np.mean(Acc)
# Out:
# 0.7829457364341085

# %%
from scipy.stats import norm
mean=meanu[CA_te[0],0]
std_dev=np.sqrt(Sigmau[CA_te[0],CA_te[0]])
mean1=meanu[RA_te[0],0]
std_dev1=np.sqrt(Sigmau[RA_te[0],RA_te[0]])
xx = np.linspace(mean - 7*std_dev, mean + 4*std_dev, 1000)
# Calculate the corresponding y-axis values using the Gaussian PDF formula
yy = norm.pdf(xx, mean, std_dev)
yy1 = norm.pdf(xx, mean1, std_dev1)
# Plot the Gaussian PDF
plt.plot(xx, yy,color='C0',label="p(u$_1$)")
plt.plot(xx, yy1[:,0],color='C1',label="p(u$_2$)")
plt.plot(xx, yy1[:,1],color='C2',label="p(u$_3$)")
plt.xlabel('u',fontsize=16)
#plt.ylabel('Probability Density')
plt.legend(fontsize=16)
plt.grid(True)
plt.show()
#plt.savefig("modecanada_choice3.pdf")

# %%
yy1
# Out:
# array([[0.00268041, 0.00400115],
#        [0.00273143, 0.00408216],
#        [0.00278332, 0.00416461],
#        ...,
#        [0.00182275, 0.00015744],
#        [0.00178724, 0.00015331],
#        [0.00175236, 0.00014928]])

# %%
Sigmau[CA_te[0],CA_te[0]]
# Out:
# Array([0.69851636], dtype=float64)

# %%
# Large format
def make_large(df,num):
    dfl = df[df.noalt==num].copy()
    dfl['s']=dfl.groupby(['case']).cumcount()+1
    dfl=dfl.set_index(['s','case']).unstack(0)
    dfl.columns=[f"{x}{y}" for x,y in dfl.columns]
    dfl.drop(columns=["noalt"+str(i) for i in range(1,num+1)],inplace=True)
    return dfl.reset_index()
dfl = make_large(df,2)
dfl=dfl.drop_duplicates(['choice1', 'choice2', 'dist1', 'dist2', 'cost1',
       'cost2', 'ivt1', 'ivt2', 'ovt1', 'ovt2', 'freq1', 'freq2'])
#dfl[dfl.duplicated([ 'dist1', 'dist2', 'cost1',
#       'cost2', 'ivt1', 'ivt2', 'ovt1', 'ovt2', 'freq1', 'freq2'],keep=False)].case.values
dfl
# Out:
#      case   alt1 alt2  choice1  choice2  dist1  dist2   cost1  cost2  ivt1  \
# 0       1  train  car        0        1     83     83   28.25  15.77    50
# 10     11  train  car        0        1    105    105   31.25  19.95    50
# 13     14  train  car        0        1    154    154   45.65  29.26   117
# 16     17  train  car        0        1    186    186   45.65  35.34   117
# 17     72  train  car        0        1    231    231   44.15  43.89   117
# ..    ...    ...  ...      ...      ...    ...    ...     ...    ...   ...
# 225  4240    air  car        0        1    150    150  155.30  28.50    46
# 226  4278  train  car        0        1    107    107   23.30  20.33    63
# 227  4292  train  car        0        1     30     30   33.40   5.70    40
# 229  4323  train  car        0        1    323    323   60.60  61.37   193
# 230  4324  train  car        0        1    150    150   28.50  28.50    63
#
#      ivt2  ovt1  ovt2  freq1  freq2  income1  income2  urban1  urban2
# 0      61    66     0      4      0       45       45       0       0
# 10     79    74     0      4      0       35       35       0       0
# 13    119   109     0      4      0       70       70       0       0
# 16    146   109     0      4      0       45       45       0       0
# 17    153    89     0      4      0       45       45       0       0
# ..    ...   ...   ...    ...    ...      ...      ...     ...     ...
# 225   134   215     0     16      0       55       55       0       0
# 226    86    63     0      1      0       25       25       0       0
# 227    33    95     0      4      0       45       45       0       0
# 229   278   200     0      3      0       45       45       0       0
# 230   134   105     0      1      0       70       70       0       0
#
# [126 rows x 19 columns]

# %%
import pandas as pd
import numpy as np 
import xgboost as xgb

# %%
np.unique(df['case'].iloc[ind_train])
# Out:
# array([   1,    4,    5,    9,   10,   12,   13,   14,   15,   16,   17,
#          72,   73,  202,  205,  227,  238,  266,  279,  280,  281,  282,
#         287,  290,  291,  293,  294,  295,  297,  298,  299,  300,  301,
#         302,  305,  307,  308,  310,  311,  314,  364,  397,  398,  399,
#         403,  425,  426,  427,  428,  429,  431,  433,  434,  435,  436,
#         477,  478,  479,  481,  482,  486,  488,  502,  503,  505,  506,
#         543,  544,  561,  562,  568,  569,  579,  580,  581,  939,  940,
#         942,  968,  969, 1008, 1009, 1012, 1013, 1015, 1016, 1060, 1084,
#        1087, 1088, 1089, 1116, 1132, 1179, 1207, 1217, 1229, 1265, 1266,
#        1267, 1831, 2609, 2864, 2865, 2867, 2868, 2869, 2870, 2871, 2872,
#        2890, 2891, 2892, 2893, 2894, 2917, 2918, 2931, 2982, 2983, 3011,
#        3013, 3014, 3025, 3026, 3028, 3029, 3039, 3040, 3042, 3044, 3045,
#        3046, 3085, 3087, 3089, 3100, 3101, 3105, 3107, 3159, 3548, 3593,
#        3662, 3731, 3732, 3733, 3735, 3736, 3737, 3738, 3739, 3806, 4091,
#        4155, 4210, 4239, 4240, 4278, 4292, 4293])

# %%
dfl
# Out:
#      case   alt1 alt2  choice1  choice2  dist1  dist2   cost1  cost2  ivt1  \
# 0       1  train  car        0        1     83     83   28.25  15.77    50
# 10     11  train  car        0        1    105    105   31.25  19.95    50
# 13     14  train  car        0        1    154    154   45.65  29.26   117
# 16     17  train  car        0        1    186    186   45.65  35.34   117
# 17     72  train  car        0        1    231    231   44.15  43.89   117
# ..    ...    ...  ...      ...      ...    ...    ...     ...    ...   ...
# 225  4240    air  car        0        1    150    150  155.30  28.50    46
# 226  4278  train  car        0        1    107    107   23.30  20.33    63
# 227  4292  train  car        0        1     30     30   33.40   5.70    40
# 229  4323  train  car        0        1    323    323   60.60  61.37   193
# 230  4324  train  car        0        1    150    150   28.50  28.50    63
#
#      ivt2  ovt1  ovt2  freq1  freq2  income1  income2  urban1  urban2
# 0      61    66     0      4      0       45       45       0       0
# 10     79    74     0      4      0       35       35       0       0
# 13    119   109     0      4      0       70       70       0       0
# 16    146   109     0      4      0       45       45       0       0
# 17    153    89     0      4      0       45       45       0       0
# ..    ...   ...   ...    ...    ...      ...      ...     ...     ...
# 225   134   215     0     16      0       55       55       0       0
# 226    86    63     0      1      0       25       25       0       0
# 227    33    95     0      4      0       45       45       0       0
# 229   278   200     0      3      0       45       45       0       0
# 230   134   105     0      1      0       70       70       0       0
#
# [126 rows x 19 columns]

# %%
dfl_train=dfl[dfl.case.isin(np.unique(df['case'].iloc[ind_train]))]
dfl_test=dfl[dfl.case.isin(np.unique(df['case'].iloc[ind_test]))]
Xl_train = dfl_train[['dist1', 'dist2', 'cost1',
       'cost2', 'ivt1', 'ivt2', 'ovt1', 'ovt2', 'freq1', 'freq2']].values
yl_train=dfl_train['choice2'].values
Xl_test = dfl_test[['dist1', 'dist2', 'cost1',
       'cost2', 'ivt1', 'ivt2', 'ovt1', 'ovt2', 'freq1', 'freq2']].values
yl_test=dfl_test['choice2'].values

scalerxl=StandardScaler().fit(Xl_train)
Xl_train_trasf=scalerxl.transform(Xl_train)
Xl_test_trasf=scalerxl.transform(Xl_test)

# %%
params = {
            'reg_lambda':1.0,
          "early_stopping_rounds":10 #to avoid overfitting
        }
eval_set = [(Xl_train_trasf, yl_train),(Xl_test_trasf, yl_test)]
XGBconstr = xgb.XGBClassifier(**params)
XGBconstr.fit(Xl_train_trasf, yl_train, 
              eval_metric=["auc","logloss"], eval_set=eval_set) #, verbose=True)
ypred_x= XGBconstr.predict(Xl_test_trasf)
# Out:
# [0]	validation_0-auc:0.96429	validation_0-logloss:0.40885	validation_1-auc:0.93678	validation_1-logloss:0.37303
# [1]	validation_0-auc:0.96939	validation_0-logloss:0.33615	validation_1-auc:0.93103	validation_1-logloss:0.32037
# [2]	validation_0-auc:0.96939	validation_0-logloss:0.29059	validation_1-auc:0.93103	validation_1-logloss:0.28942
# [3]	validation_0-auc:0.97925	validation_0-logloss:0.25727	validation_1-auc:0.93103	validation_1-logloss:0.25632
# [4]	validation_0-auc:0.98537	validation_0-logloss:0.22563	validation_1-auc:0.94828	validation_1-logloss:0.22525
# [5]	validation_0-auc:0.98571	validation_0-logloss:0.20360	validation_1-auc:0.95977	validation_1-logloss:0.20542
# [6]	validation_0-auc:0.98810	validation_0-logloss:0.18847	validation_1-auc:0.95977	validation_1-logloss:0.19549
# [7]	validation_0-auc:0.98741	validation_0-logloss:0.17903	validation_1-auc:0.95977	validation_1-logloss:0.18587
# [8]	validation_0-auc:0.98878	validation_0-logloss:0.16789	validation_1-auc:0.95977	validation_1-logloss:0.18694
# [9]	validation_0-auc:0.99082	validation_0-logloss:0.15759	validation_1-auc:0.95977	validation_1-logloss:0.17944
# [10]	validation_0-auc:0.99150	validation_0-logloss:0.14810	validation_1-auc:0.95977	validation_1-logloss:0.17301
# [11]	validation_0-auc:0.99218	validation_0-logloss:0.14302	validation_1-auc:0.95977	validation_1-logloss:0.17349
# [12]	validation_0-auc:0.99150	validation_0-logloss:0.13865	validation_1-auc:0.95977	validation_1-logloss:0.17401
# [13]	validation_0-auc:0.99218	validation_0-logloss:0.13247	validation_1-auc:0.95977	validation_1-logloss:0.16984
# [14]	validation_0-auc:0.99218	validation_0-logloss:0.12980	validation_1-auc:0.95977	validation_1-logloss:0.16880
# [15]	validation_0-auc:0.99218	validation_0-logloss:0.12786	validation_1-auc:0.95977	validation_1-logloss:0.16728
# [16]	validation_0-auc:0.99286	validation_0-logloss:0.12371	validation_1-auc:0.95977	validation_1-logloss:0.16499
# [17]	validation_0-auc:0.99286	validation_0-logloss:0.12109	validation_1-auc:0.94828	validation_1-logloss:0.16797
# [18]	validation_0-auc:0.99354	validation_0-logloss:0.11943	validation_1-auc:0.94828	validation_1-logloss:0.16746
# [19]	validation_0-auc:0.99286	validation_0-logloss:0.11774	validation_1-auc:0.94828	validation_1-logloss:0.17074
# [20]	validation_0-auc:0.99354	validation_0-logloss:0.11513	validation_1-auc:0.94828	validation_1-logloss:0.16994
# [21]	validation_0-auc:0.99354	validation_0-logloss:0.11332	validation_1-auc:0.94828	validation_1-logloss:0.17211
# [22]	validation_0-auc:0.99354	validation_0-logloss:0.11241	validation_1-auc:0.94828	validation_1-logloss:0.17423
# [23]	validation_0-auc:0.99354	validation_0-logloss:0.11155	validation_1-auc:0.94828	validation_1-logloss:0.17422
# [24]	validation_0-auc:0.99354	validation_0-logloss:0.11049	validation_1-auc:0.94828	validation_1-logloss:0.17410
# [25]	validation_0-auc:0.99354	validation_0-logloss:0.10916	validation_1-auc:0.94828	validation_1-logloss:0.17394
# [26]	validation_0-auc:0.99354	validation_0-logloss:0.10851	validation_1-auc:0.94828	validation_1-logloss:0.17597
# [27]	validation_0-auc:0.99354	validation_0-logloss:0.10780	validation_1-auc:0.94828	validation_1-logloss:0.17607
# [28]	validation_0-auc:0.99354	validation_0-logloss:0.10663	validation_1-auc:0.94828	validation_1-logloss:0.17846
# [29]	validation_0-auc:0.99422	validation_0-logloss:0.10563	validation_1-auc:0.94828	validation_1-logloss:0.17962
# [30]	validation_0-auc:0.99354	validation_0-logloss:0.10503	validation_1-auc:0.94828	validation_1-logloss:0.18120
# [31]	validation_0-auc:0.99354	validation_0-logloss:0.10464	validation_1-auc:0.94828	validation_1-logloss:0.18072
# [32]	validation_0-auc:0.99354	validation_0-logloss:0.10376	validation_1-auc:0.94828	validation_1-logloss:0.18082
# [33]	validation_0-auc:0.99354	validation_0-logloss:0.10331	validation_1-auc:0.94828	validation_1-logloss:0.18239
# [34]	validation_0-auc:0.99354	validation_0-logloss:0.10275	validation_1-auc:0.94828	validation_1-logloss:0.18241
# [35]	validation_0-auc:0.99354	validation_0-logloss:0.10235	validation_1-auc:0.94828	validation_1-logloss:0.18424
# [36]	validation_0-auc:0.99422	validation_0-logloss:0.10189	validation_1-auc:0.94828	validation_1-logloss:0.18432
# [37]	validation_0-auc:0.99422	validation_0-logloss:0.10160	validation_1-auc:0.94828	validation_1-logloss:0.18606
# [38]	validation_0-auc:0.99354	validation_0-logloss:0.10114	validation_1-auc:0.94828	validation_1-logloss:0.18769
# [39]	validation_0-auc:0.99354	validation_0-logloss:0.10044	validation_1-auc:0.94828	validation_1-logloss:0.18805
# [40]	validation_0-auc:0.99422	validation_0-logloss:0.09991	validation_1-auc:0.94828	validation_1-logloss:0.18779
# [41]	validation_0-auc:0.99422	validation_0-logloss:0.09953	validation_1-auc:0.94828	validation_1-logloss:0.18782
#  /home/benavoli/anaconda3/envs/myenv/lib/python3.9/site-packages/xgboost/sklearn.py:885: UserWarning:`eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.

# %%
accuracy_score(ypred_x,yl_test)
# Out:
# 0.9142857142857143

# %%
Y_pred=m.predict(X_te_n)[0]
np.mean((Y_pred>0.5)==Y_te)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-c7ebef02d81a> in <module>
# ----> 1 Y_pred=m.predict(X_te_n)[0]
#       2 np.mean((Y_pred>0.5)==Y_te)
#
# NameError: name 'm' is not defined

# %%
# Out:
# False

# %%
m.predict(X_te_n)
# Out:
# (array([[0.078184  ],
#         [0.91605766],
#         [0.05717934],
#         [0.08390796],
#         [0.07551436],
#         [0.09316835],
#         [0.060072  ],
#         [0.06612089],
#         [0.07558736],
#         [0.9288635 ],
#         [0.31934312],
#         [0.7697965 ],
#         [0.42635585],
#         [0.66943297],
#         [0.42210054],
#         [0.78558023],
#         [0.35076472],
#         [0.5       ],
#         [0.43548261],
#         [0.41594431],
#         [0.8241773 ],
#         [0.81577496],
#         [0.19019815],
#         [0.83314615],
#         [0.76768611],
#         [0.8866981 ],
#         [0.21787981],
#         [0.12819139],
#         [0.15655527],
#         [0.6949131 ],
#         [0.104309  ],
#         [0.17880167],
#         [0.88913212],
#         [0.92652544],
#         [0.88808796],
#         [0.18194804],
#         [0.74974725],
#         [0.78779424],
#         [0.05930568],
#         [0.90138765],
#         [0.92108561],
#         [0.92099835],
#         [0.05911075],
#         [0.88508589],
#         [0.10103457],
#         [0.11716941],
#         [0.87040212],
#         [0.146515  ],
#         [0.08501303],
#         [0.14286115],
#         [0.10472851],
#         [0.9110121 ],
#         [0.09339138],
#         [0.11099387],
#         [0.06137078],
#         [0.06820272],
#         [0.93201675],
#         [0.07244597],
#         [0.95364065],
#         [0.96419171],
#         [0.05990193],
#         [0.11898652],
#         [0.89581531],
#         [0.03918734],
#         [0.03785494],
#         [0.95008078],
#         [0.94080549],
#         [0.94275646],
#         [0.91673872],
#         [0.92225145],
#         [0.94829378],
#         [0.05159401],
#         [0.05926945],
#         [0.95221728],
#         [0.06095484],
#         [0.06925376],
#         [0.61466727],
#         [0.2624498 ],
#         [0.56676164],
#         [0.5       ],
#         [0.67922993],
#         [0.71717304],
#         [0.59878175],
#         [0.26222224],
#         [0.4332384 ],
#         [0.65969702],
#         [0.36761475],
#         [0.63082765],
#         [0.53519641],
#         [0.65985124],
#         [0.44226742],
#         [0.60057184],
#         [0.17719548],
#         [0.9539845 ],
#         [0.14019253],
#         [0.12220334],
#         [0.92652832],
#         [0.90305509],
#         [0.05198376],
#         [0.89358092],
#         [0.12163887],
#         [0.88246547],
#         [0.88072437],
#         [0.11041586],
#         [0.87813555],
#         [0.94119546],
#         [0.05839457],
#         [0.91423007],
#         [0.91934888],
#         [0.9561757 ],
#         [0.08614662],
#         [0.08852231],
#         [0.92827206],
#         [0.92993153],
#         [0.07195325],
#         [0.93135172],
#         [0.89788593],
#         [0.93929963],
#         [0.90447045],
#         [0.09762138],
#         [0.40446324],
#         [0.42372995],
#         [0.42269617],
#         [0.5       ],
#         [0.530457  ],
#         [0.56527784],
#         [0.58014499],
#         [0.68427819],
#         [0.35010003],
#         [0.39550222],
#         [0.530457  ],
#         [0.63555276],
#         [0.59872249],
#         [0.4643034 ],
#         [0.93142867],
#         [0.06470482],
#         [0.92706478],
#         [0.09095047],
#         [0.93932309],
#         [0.92741966],
#         [0.93737346],
#         [0.05354339],
#         [0.05286652],
#         [0.07116493],
#         [0.06137959],
#         [0.05730935],
#         [0.06779885],
#         [0.89758219],
#         [0.86485283],
#         [0.06973167],
#         [0.09450161],
#         [0.93900783],
#         [0.90660043],
#         [0.10571374],
#         [0.12083035],
#         [0.91890938],
#         [0.09682183],
#         [0.88489652],
#         [0.93564996],
#         [0.93712536],
#         [0.2013338 ],
#         [0.29662318],
#         [0.90865364],
#         [0.88680157],
#         [0.41467932],
#         [0.34768829],
#         [0.28119102],
#         [0.07633437],
#         [0.83231847],
#         [0.75610533],
#         [0.26644187],
#         [0.79071734],
#         [0.87296518],
#         [0.30176158],
#         [0.60362493],
#         [0.74345746],
#         [0.68566961],
#         [0.36971148],
#         [0.4190529 ],
#         [0.20873812],
#         [0.63175533],
#         [0.36971148],
#         [0.50869237],
#         [0.34862893],
#         [0.47825928],
#         [0.64211595],
#         [0.38697921],
#         [0.53550669],
#         [0.58824453],
#         [0.66737547],
#         [0.2727265 ],
#         [0.23498435],
#         [0.88342855],
#         [0.80173788],
#         [0.80642632],
#         [0.81322349],
#         [0.4207496 ],
#         [0.30827522],
#         [0.79742336],
#         [0.88825261],
#         [0.75163459],
#         [0.58562104],
#         [0.88992403],
#         [0.93772449],
#         [0.07285189],
#         [0.05673181],
#         [0.94169428],
#         [0.91299505],
#         [0.91854949],
#         [0.94355937],
#         [0.0658109 ],
#         [0.93150317],
#         [0.06261161],
#         [0.05935189],
#         [0.07680963],
#         [0.92620529],
#         [0.06697457],
#         [0.92891753],
#         [0.881593  ],
#         [0.07886605],
#         [0.05553111],
#         [0.06893782],
#         [0.04666311],
#         [0.91111349],
#         [0.08961845],
#         [0.88956336],
#         [0.94479119],
#         [0.84631099],
#         [0.88339829],
#         [0.90014672],
#         [0.10345873],
#         [0.90261993],
#         [0.95621401],
#         [0.10034641],
#         [0.06033547],
#         [0.88286299],
#         [0.12651827],
#         [0.94515065],
#         [0.0582187 ],
#         [0.94251722],
#         [0.06938337],
#         [0.92916905],
#         [0.91874262],
#         [0.05547406],
#         [0.92959318],
#         [0.93134711],
#         [0.04391999],
#         [0.35155103],
#         [0.68267423],
#         [0.65969528],
#         [0.3279984 ],
#         [0.68824944],
#         [0.21453052],
#         [0.6330754 ],
#         [0.67232007],
#         [0.69663243],
#         [0.69506356],
#         [0.76752953],
#         [0.11759157],
#         [0.75425479],
#         [0.83790074],
#         [0.80614471],
#         [0.77188282],
#         [0.81029842],
#         [0.85350743],
#         [0.30091123],
#         [0.67196126],
#         [0.29685212],
#         [0.35477649],
#         [0.33613392],
#         [0.35792103],
#         [0.40916595],
#         [0.6879588 ],
#         [0.28475712],
#         [0.66409174],
#         [0.76397969],
#         [0.41061325],
#         [0.40835359],
#         [0.38269152],
#         [0.77456628],
#         [0.91723066],
#         [0.90850983],
#         [0.91545689],
#         [0.0699941 ],
#         [0.07803959],
#         [0.89858506],
#         [0.89469715],
#         [0.93084365],
#         [0.90391146],
#         [0.90929871],
#         [0.88996558],
#         [0.92508351],
#         [0.88699245],
#         [0.08481405],
#         [0.07183913],
#         [0.10464661],
#         [0.10444151],
#         [0.09227564],
#         [0.80356705],
#         [0.10006416],
#         [0.89421081],
#         [0.85897426],
#         [0.92446044],
#         [0.86317148],
#         [0.1298996 ],
#         [0.12773513],
#         [0.09084732],
#         [0.07637714],
#         [0.8969553 ],
#         [0.14111433],
#         [0.84415892],
#         [0.93593127],
#         [0.05421656],
#         [0.06465238],
#         [0.0632053 ],
#         [0.06240891],
#         [0.90685434],
#         [0.06952996],
#         [0.05510451],
#         [0.93258075],
#         [0.06079409],
#         [0.93461615],
#         [0.07398866],
#         [0.07303496],
#         [0.83939957],
#         [0.20760833],
#         [0.38936486],
#         [0.64957681],
#         [0.72032816],
#         [0.71315595],
#         [0.20900814],
#         [0.70609816],
#         [0.36839827],
#         [0.75146169],
#         [0.65312979],
#         [0.18457811],
#         [0.20732545],
#         [0.74246703],
#         [0.8263788 ],
#         [0.90907061],
#         [0.69977385],
#         [0.78939184],
#         [0.8859788 ],
#         [0.78778969],
#         [0.29923741],
#         [0.89478186],
#         [0.78657674],
#         [0.84228578],
#         [0.74306655],
#         [0.12796829],
#         [0.79988351],
#         [0.80864004],
#         [0.07996488],
#         [0.48130361],
#         [0.5       ],
#         [0.47154481],
#         [0.5       ],
#         [0.49228131],
#         [0.50771869],
#         [0.5187168 ],
#         [0.5       ],
#         [0.5       ],
#         [0.5       ],
#         [0.5       ],
#         [0.52845519],
#         [0.5       ],
#         [0.5       ],
#         [0.61295493],
#         [0.60841345],
#         [0.39212035],
#         [0.5       ],
#         [0.5       ],
#         [0.5       ],
#         [0.60787965],
#         [0.5       ],
#         [0.16660483],
#         [0.88123199],
#         [0.88987906],
#         [0.82536925],
#         [0.08364282],
#         [0.06491956],
#         [0.89990287],
#         [0.81382096],
#         [0.21377881],
#         [0.07253333],
#         [0.1393652 ],
#         [0.92606369],
#         [0.14596681],
#         [0.09935931],
#         [0.85144503],
#         [0.14328012],
#         [0.89144124],
#         [0.13526374],
#         [0.08497479],
#         [0.88034651],
#         [0.87199114],
#         [0.08507873],
#         [0.94422772],
#         [0.916619  ],
#         [0.91184909],
#         [0.91948077],
#         [0.93503083],
#         [0.06260791],
#         [0.88953543],
#         [0.07820615],
#         [0.90760439],
#         [0.0700457 ],
#         [0.08022561],
#         [0.07311918],
#         [0.10405366],
#         [0.08911796],
#         [0.92088367],
#         [0.92382534],
#         [0.83492143],
#         [0.85939059],
#         [0.07026391],
#         [0.9304342 ],
#         [0.05181166],
#         [0.94476424],
#         [0.93165461],
#         [0.07503   ],
#         [0.04809453],
#         [0.0698003 ],
#         [0.0485061 ],
#         [0.07235967],
#         [0.08925341],
#         [0.07645319],
#         [0.93097837],
#         [0.0868158 ],
#         [0.9397453 ],
#         [0.08811132],
#         [0.1381187 ],
#         [0.08750852],
#         [0.10166026],
#         [0.8638278 ],
#         [0.07426609],
#         [0.90921387],
#         [0.08464007],
#         [0.9245677 ],
#         [0.15327042],
#         [0.9122999 ],
#         [0.09789215],
#         [0.92258042],
#         [0.36745746],
#         [0.75148422],
#         [0.66836634],
#         [0.65734646],
#         [0.72642421],
#         [0.29581463],
#         [0.40119523],
#         [0.27284025],
#         [0.6151283 ],
#         [0.63571854],
#         [0.61273099],
#         [0.71587008],
#         [0.88234095],
#         [0.87421962],
#         [0.1210681 ],
#         [0.1167134 ],
#         [0.13287961],
#         [0.14419885],
#         [0.90373251],
#         [0.14670931],
#         [0.10648948],
#         [0.89255078],
#         [0.15176468],
#         [0.90579495],
#         [0.1184244 ],
#         [0.9413377 ],
#         [0.06000193],
#         [0.87809154],
#         [0.09816746],
#         [0.05368709],
#         [0.93535346],
#         [0.91027283],
#         [0.13033714],
#         [0.89852317],
#         [0.94184491],
#         [0.12814786],
#         [0.94581805],
#         [0.07506979],
#         [0.8986083 ],
#         [0.93997237],
#         [0.9128571 ],
#         [0.0420224 ],
#         [0.91273959],
#         [0.06154754],
#         [0.07606179],
#         [0.91536204],
#         [0.06868558],
#         [0.93911063],
#         [0.9376463 ],
#         [0.05983807],
#         [0.04925013],
#         [0.06096352],
#         [0.93049707],
#         [0.9189447 ],
#         [0.92952304],
#         [0.92719252],
#         [0.05956855],
#         [0.06561098],
#         [0.14891354],
#         [0.09150949],
#         [0.14528308],
#         [0.7779119 ],
#         [0.24847907],
#         [0.83226287],
#         [0.129886  ],
#         [0.88235509],
#         [0.13722216],
#         [0.76271738],
#         [0.15092536],
#         [0.19473779],
#         [0.20223876],
#         [0.79002145],
#         [0.07812458],
#         [0.90261082],
#         [0.06250691],
#         [0.86345157],
#         [0.91634665],
#         [0.89074092],
#         [0.89219876],
#         [0.9354751 ],
#         [0.89138305],
#         [0.77583851],
#         [0.14585377],
#         [0.10907013],
#         [0.10717462],
#         [0.12528195],
#         [0.11052623],
#         [0.84167412],
#         [0.20102765],
#         [0.86101471],
#         [0.93075293],
#         [0.89207944],
#         [0.88838885],
#         [0.87826591],
#         [0.06483882],
#         [0.0768551 ],
#         [0.20532618],
#         [0.22403671],
#         [0.82919913],
#         [0.15890655],
#         [0.12145934],
#         [0.23241421],
#         [0.15827212],
#         [0.76790877],
#         [0.15706179],
#         [0.86402986],
#         [0.19364567],
#         [0.16578227],
#         [0.81946755],
#         [0.87715301],
#         [0.17070339],
#         [0.13358364],
#         [0.07683569],
#         [0.95016079],
#         [0.92994641],
#         [0.93500773],
#         [0.08041952],
#         [0.05744841],
#         [0.93066435],
#         [0.96418946],
#         [0.06527012],
#         [0.91585678],
#         [0.89177408],
#         [0.07415092],
#         [0.83840285],
#         [0.85686541],
#         [0.17127606],
#         [0.08053217],
#         [0.85449899],
#         [0.83826008],
#         [0.81490912],
#         [0.87914434],
#         [0.7642517 ],
#         [0.22743123],
#         [0.90084185],
#         [0.87668028],
#         [0.1346343 ],
#         [0.85878797],
#         [0.06782525],
#         [0.90877927],
#         [0.11445969],
#         [0.8476577 ],
#         [0.12905661],
#         [0.86202274],
#         [0.10428717],
#         [0.12264614],
#         [0.86203051],
#         [0.11351009],
#         [0.8860752 ],
#         [0.91867346],
#         [0.15996294],
#         [0.2298857 ],
#         [0.10522575],
#         [0.19117483],
#         [0.17486077],
#         [0.1536245 ],
#         [0.19342871],
#         [0.80185236],
#         [0.83696986],
#         [0.16350936],
#         [0.14561442],
#         [0.11729279],
#         [0.82360448],
#         [0.85181938],
#         [0.87518792],
#         [0.17219308],
#         [0.85078797],
#         [0.1453332 ],
#         [0.85649843],
#         [0.93875451],
#         [0.09551275],
#         [0.088405  ],
#         [0.91269268],
#         [0.11841802],
#         [0.12261384],
#         [0.06075887],
#         [0.13760998],
#         [0.08706146],
#         [0.81544379],
#         [0.17754193],
#         [0.87507839],
#         [0.65219493],
#         [0.37370981],
#         [0.60770061],
#         [0.70391088],
#         [0.66903146],
#         [0.65808159],
#         [0.27756852],
#         [0.60740898],
#         [0.61983547],
#         [0.37109578],
#         [0.71793099],
#         [0.38726007],
#         [0.72990464],
#         [0.32919575],
#         [0.23917787],
#         [0.27498065],
#         [0.28203607],
#         [0.66827744],
#         [0.31196635],
#         [0.5       ],
#         [0.136773  ],
#         [0.39408249],
#         [0.44499811],
#         [0.41089808],
#         [0.77218668],
#         [0.33172257],
#         [0.21827629],
#         [0.4567485 ],
#         [0.87819558],
#         [0.36037525],
#         [0.60591751],
#         [0.06260529],
#         [0.85439587],
#         [0.06665269],
#         [0.92364301],
#         [0.06151198],
#         [0.926759  ],
#         [0.87503445],
#         [0.0956926 ],
#         [0.931717  ],
#         [0.09031789],
#         [0.89438888],
#         [0.92827444],
#         [0.09300978],
#         [0.91460232],
#         [0.06429417],
#         [0.82453904],
#         [0.9187334 ],
#         [0.20114236],
#         [0.92225603],
#         [0.77280361],
#         [0.86956538],
#         [0.13753611],
#         [0.15581175],
#         [0.81351626],
#         [0.87315921],
#         [0.88387403],
#         [0.8708428 ],
#         [0.90598678],
#         [0.93429833],
#         [0.08922466],
#         [0.93811528],
#         [0.92419723],
#         [0.94677886],
#         [0.07643115],
#         [0.93140326],
#         [0.07521636],
#         [0.94185089],
#         [0.93578732],
#         [0.0765916 ],
#         [0.07329062],
#         [0.08256512],
#         [0.07822668],
#         [0.93339895],
#         [0.92465297],
#         [0.06230042],
#         [0.05739092],
#         [0.08231109],
#         [0.89460823],
#         [0.12849504],
#         [0.09938961],
#         [0.08922056],
#         [0.92654585],
#         [0.06436292],
#         [0.10311046],
#         [0.90747922],
#         [0.05924767],
#         [0.04538513],
#         [0.08961383],
#         [0.77885676],
#         [0.86081524],
#         [0.07363846],
#         [0.86294871],
#         [0.11632933],
#         [0.91638005],
#         [0.08899664],
#         [0.19267351],
#         [0.86892699],
#         [0.84699438],
#         [0.92180035],
#         [0.90756605],
#         [0.1608562 ],
#         [0.85016496],
#         [0.08446257],
#         [0.88838131],
#         [0.8299636 ],
#         [0.74622508],
#         [0.18273117],
#         [0.82868759],
#         [0.15678111],
#         [0.9143531 ],
#         [0.87876085],
#         [0.89173488],
#         [0.94043602],
#         [0.93563784],
#         [0.08717664],
#         [0.94215045],
#         [0.07699675],
#         [0.08912432],
#         [0.91027231],
#         [0.06456342],
#         [0.93407434],
#         [0.92816286],
#         [0.09631466],
#         [0.14364983],
#         [0.85183414],
#         [0.07774572],
#         [0.12100045],
#         [0.83046958],
#         [0.8616576 ],
#         [0.10644576],
#         [0.95106448],
#         [0.0725342 ],
#         [0.91809109],
#         [0.04348056],
#         [0.93660002],
#         [0.04936951],
#         [0.95160435],
#         [0.07815099],
#         [0.16014119],
#         [0.1854111 ],
#         [0.14790261],
#         [0.85766861],
#         [0.77206693],
#         [0.86115282],
#         [0.79290125],
#         [0.84854223],
#         [0.82037225],
#         [0.76380975],
#         [0.18951062],
#         [0.93624207],
#         [0.09369027],
#         [0.0734907 ],
#         [0.12138267],
#         [0.14809839],
#         [0.05537774],
#         [0.08931961],
#         [0.93141608],
#         [0.0730848 ],
#         [0.89967433],
#         [0.90552731],
#         [0.08498772],
#         [0.93958394],
#         [0.9467929 ],
#         [0.09232693],
#         [0.94243337],
#         [0.11030221],
#         [0.07914828],
#         [0.08699781],
#         [0.95925981],
#         [0.20803693],
#         [0.78827807],
#         [0.32313515],
#         [0.60775676],
#         [0.37585706],
#         [0.61982927],
#         [0.54243267],
#         [0.18241889],
#         [0.70402374],
#         [0.89048148],
#         [0.15338915],
#         [0.87971374],
#         [0.07313374],
#         [0.87470176],
#         [0.94796661],
#         [0.09064596],
#         [0.11613178],
#         [0.11511748],
#         [0.91901306],
#         [0.12187713],
#         [0.89394413],
#         [0.04818437],
#         [0.08505109],
#         [0.1142361 ],
#         [0.91741387],
#         [0.88949943],
#         [0.76340671],
#         [0.16755657],
#         [0.93378791],
#         [0.08997326],
#         [0.12489734],
#         [0.09130007],
#         [0.11969151],
#         [0.168752  ],
#         [0.82873215],
#         [0.87731416],
#         [0.94656798],
#         [0.91345048],
#         [0.10096479],
#         [0.07292621],
#         [0.9472612 ],
#         [0.86592727],
#         [0.10351081],
#         [0.05679165],
#         [0.11236651],
#         [0.06107882],
#         [0.06299066],
#         [0.05436186],
#         [0.06338051],
#         [0.93169051],
#         [0.90394029],
#         [0.07257532],
#         [0.90457587],
#         [0.05834681],
#         [0.89809753],
#         [0.14828354],
#         [0.90618626],
#         [0.85870592],
#         [0.91676742],
#         [0.15531222],
#         [0.06690532],
#         [0.9028411 ],
#         [0.92186024],
#         [0.93658812],
#         [0.08225457],
#         [0.87267644],
#         [0.95589403],
#         [0.08304074],
#         [0.10521339],
#         [0.88155955],
#         [0.86800891],
#         [0.93584341],
#         [0.94313273],
#         [0.5       ],
#         [0.43119144],
#         [0.57836476],
#         [0.28571769],
#         [0.3900505 ],
#         [0.40381403],
#         [0.42163524],
#         [0.59560158],
#         [0.40381403],
#         [0.32465615],
#         [0.34471903],
#         [0.58913723],
#         [0.75236892],
#         [0.5       ],
#         [0.5       ],
#         [0.88676153],
#         [0.08422671],
#         [0.85225102],
#         [0.06225783],
#         [0.93397291],
#         [0.05678444],
#         [0.866061  ],
#         [0.12501866],
#         [0.0533802 ],
#         [0.14720617],
#         [0.5       ],
#         [0.38942572],
#         [0.62166548],
#         [0.26348077],
#         [0.61057428],
#         [0.5       ],
#         [0.5       ],
#         [0.38942572],
#         [0.40515104],
#         [0.60925516],
#         [0.5       ],
#         [0.5       ],
#         [0.5       ],
#         [0.40515104],
#         [0.59484896],
#         [0.5       ]]),
#  nan)
