# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append('../')   
import numpy as np
from model.exactPreference import  exactPreference
from model.LuceJND import  LuceJND
from model.erroneousPreference import  erroneousPreference
from model.gaussianNoisePreferenceFull import  gaussianNoisePreference
from kernel import RBF
from utility import  paramz
# for plotting
import matplotlib.pyplot as plt
import arviz as az

def bmatrixu(a):
    """Returns a LaTeX bmatrix

    :a: numpy array
    :returns: LaTeX bmatrix as a string
    """
    if len(a.shape) > 2:
        raise ValueError('bmatrix can at most display two dimensions')
    lines = str(a).replace('[', '').replace(']', '').splitlines()
    rv = [r'\begin{bmatrix}']
    rv += ['  ' + ' & '.join(l.split()) + r'\\' for l in lines]
    rv +=  [r'\end{bmatrix}']
    return '\n'.join(rv)

# %% [markdown]
# # Thermal comfort
#
# To introduce the concepts, we make use of a simple  running example: learning Alice's  preferred home temperature.
# We present Alice with pairs of temperatures (in Celsius) and ask her preferred value. Imagine Alice's utility is as depicted in the below figure.
# In order to infer her utility function, we consider the set of temperatures (objects) $\mathcal{X}=\{10,11,12,\dots,25\}$ and asks her preferences for $20$ pairs of temperatures. This results in the dataset:
# \begin{align}
# \nonumber
# \mathcal{D}_{20}=&\{12\succ 10,13\succ 25,14\succ 13,15\succ 22,15\succ 23,16\succ 11,19\succ 15,19\succ 21,19\succ 22,\\
# \label{eq:tempdataset}
# &19\succ 24,20\succ 10,20\succ 14,20\succ 21,20\succ 24,20\succ 25,21\succ 13,21\succ 25,23\succ 25,24\succ 25\}.
# \end{align}
# We aim to learn Alice's utility function for home-temperature from $\mathcal{D}_{20}$ and predict her preferences for any other pairs of temperatures.

# %% [markdown]
# ## Alice's true utility function

# %%
np.random.seed(42)
bounds=[[10,25]]
def fun(x,noise=0):
    return 0.3*np.exp(-(x-15)**2/5)+0.5*np.exp(-(x-20)**2/2)+0.2*np.exp(-(x-23)**2/1)+noise
Xpred=np.linspace(bounds[0][0],bounds[0][1],201)[:,None]

plt.plot(Xpred[:,0],fun(Xpred[:,0]))
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.grid()
#plt.savefig("ThermalHouse.pdf")

# %% [markdown]
# ## Consistent preference model
#
# We generate `m` consistent preferences by selecting `n` random temperatures (objects). In other words, we assume Alice is rational - she does not make mistakes in expressing her preferences. We simulate her preferences here below based on the above utility.

# %%
n=15#number of objects
X=np.round(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])

m=20  
#generate preference pairs
Pairs=[]
for ii in range(m):
    np.random.seed(ii)
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        if fun(X[i])>fun(X[j]):
            Pairs.append([i,j])# i is preferred to j
        else:
            Pairs.append([j,i])# j is preferred to i
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)#remove any duplicate pair

# %% [markdown]
# Our aim is to infer Alice's utility $u$ from the dataset of pairwise preferences above.  We will then use the
# learned model to predict Alice's preference other pairs of temperatures. We place a GP prior on $u$ and use the RBF kernel and estimate the utility from the preferences.

# %% [markdown]
# We now run the exactPreference model to learn the utility function of Alice from the preference pairs.

# %%
# Data dictionary
data = {}
data["Pairs"] = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.5*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 20.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([1.0]), 
                        'range':np.vstack([[1.0, 1.0001]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


#define preference model 
model = exactPreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=60000, tune=5000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.grid()
#plt.savefig("Thermal_post_20.pdf")
# Out:
#   0%|          | 236/65000 [00:00<00:53, 1221.47it/s]
# Iteration 0  -11.06690664882905
# {'lengthscale': {'value': array([1.49585293]), 'range': array([[ 0.1, 20. ]]), 'transform': <utility.paramz.logexp object at 0x7f48ffe1cca0>}, 'variance': {'value': array([1.]), 'range': array([[1.    , 1.0001]]), 'transform': <utility.paramz.logexp object at 0x7f48ffe1cb80>}}
# 100%|██████████| 65000/65000 [00:40<00:00, 1615.90it/s]
# <ipython-input-4-696fc80c0762>:29: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %% [markdown]
# We can now predict Alice's preferences for the temperature 20 versus 18

# %%
az.plot_density(predictions[134,:]-predictions[107,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(20)-u(18)",fontsize=16)
#plt.savefig("Thermal20_u20_18.pdf")
# Out:
# Text(0.5, 0, 'u(20)-u(18)')

# %% [markdown]
# ## Limit of Discernibility (Luce's model)
#
# All asymmetric and negatively transitive preference relations can be thought to be originated by a utility function according to:
# $$
# x \succ y ~\textit{ iff }~ u(x)>u(y).
# $$
# However, consider two objects $x,y$  whose utilities can barely be discerned by Alice, and a third object  $z$  whose utility is between that of  $x$ and $y$. In this case, Alice may either not be able to state her preference
# for $z$ compared to $x,y$ (violating negative transitivity), or state a wrong preference (violating asymmetry or negative transitivity).

# %% [markdown]
# We consider the home-temperature  example, whose true utility function was defined previously.  We assume that two temperatures ${ x}_i,{ x}_j$ are indiscernible by Alice whenever $|u({ x}_i)-u({ x}_j)|\leq \delta$ ($\delta=0.025$ in the below example). In order to infer Alice's utility function, we consider the set of temperatures (objects) $\mathcal{X}=\{10,11,12,\dots,25\}$ and asks her preferences for $20$ pairs of temperatures. We simulate her preferences here below.

# %%
n=15#number of objects
X=np.round(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])


m=20 
delta =0.025 
#generate preference matrix
Pairs=[]
Pairs_ind = []
for ii in range(m):
    np.random.seed(ii)
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        if fun(X[i])>fun(X[j])+delta:
            Pairs.append([i,j])# i is preferred to j
        elif fun(X[j])>fun(X[i])+delta:
            Pairs.append([j,i])# j is preferred to i
        else:
            Pairs_ind.append([i,j])# j is indisc. to j
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)
Pairs_ind, indices = np.unique(np.sort(Pairs_ind,axis=1), axis=0, return_index=True)
#Pairs_ind

# %% [markdown]
# We now run the LuceJND model to learn the utility function of Alice from the preference pairs.

# %%
# Data dictionary
data = {}
data["Pairs"]  = Pairs
data["Indisc"] = Pairs_ind
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.5*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 20.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([5.0]), 
                        'range':np.vstack([[5.0, 5.01]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


#define preference model 
model = LuceJND(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=60000, tune=5000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
# Out:
#   0%|          | 0/65000 [00:00<?, ?it/s]/home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/slice_sampler.py:154: RuntimeWarning: invalid value encountered in sqrt
#   thetas_1=2*np.arctan2(nu-np.sqrt(r_sq -b**2),x0+b)#+np.pi
# /home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/slice_sampler.py:155: RuntimeWarning: invalid value encountered in sqrt
#   thetas_2=2*np.arctan2(nu+np.sqrt(r_sq -b**2),x0+b)#+np.pi
#   0%|          | 173/65000 [00:00<00:37, 1721.28it/s]
# {'lengthscale': {'value': array([1.5]), 'range': array([[ 0.1, 20. ]]), 'transform': <utility.paramz.logexp object at 0x7f48f10be0a0>}, 'variance': {'value': array([5.]), 'range': array([[5.  , 5.01]]), 'transform': <utility.paramz.logexp object at 0x7f48f10be190>}}
# 100%|██████████| 65000/65000 [00:38<00:00, 1669.31it/s]
# <ipython-input-8-d2c3b205b39e>:30: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.grid()
#plt.savefig("Thermal_post_20_JND.pdf")

# %% [markdown]
# We can then predict Alice's preferences and also predicts when she cannot discerne two temperatures to the limit of discernability

# %%
az.plot_density(predictions[134,:]-predictions[107,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(20)-u(18)",fontsize=16)
#plt.savefig("Thermal20_u20_18_JND.pdf")
# Out:
# Text(0.5, 0, 'u(20)-u(18)')

# %%
# inside the JND
az.plot_density(predictions[67,:]-predictions[120,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(15)-u(19)",fontsize=16)
#plt.savefig("Thermal40_u15_19_JND.pdf")
# Out:
# Text(0.5, 0, 'u(15)-u(19)')

# %%
az.plot_density(predictions[40,:]-predictions[107,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(13)-u(18)",fontsize=16)
#plt.savefig("Thermal20_u13_18_JND.pdf")
# Out:
# Text(0.5, 0, 'u(13)-u(18)')

# %% [markdown]
# ## Probit Erroneous preference model
#
# Luce introduced an interval of no noticeable difference to model  Alice's absence of strict preference between two indiscernible objects  $x , y$. However, there are applications where Alice is forced to express her preference between   $x , y$ even when the two objects are indiscernible.
#
# This will result in wrong preference statements -- Alice may state   $y \succ x$ when $u(x)>u(y)$ -- overall leading to violations of asymmetry and negative transitivity. The probability of correctly stating $x \succ y$  is a function of the difference $u(x)-u(y)$, which can be  modelled by  the following likelihood:
# $$
# p(x \succ y|u)=\Phi\left(\frac{u(x)-u(y)}{\sigma}\right),
# $$
# where $\Phi(\cdot)$ is the Cumulative Distribution Function (CDF) of the
# standard Normal distribution. $\sigma>0$ is a scaling parameter, which plays a similar role to $\delta$ in Luce's model.

# %%
# plot of the Probit function
from scipy.stats import norm
deltau = np.linspace(-0.1,0.1,100)
plt.plot(deltau,norm.cdf(deltau/0.025),label="$\\sigma=0.025$")
plt.plot(deltau,norm.cdf(deltau/0.05),label="$\\sigma=0.05$")
plt.plot(deltau,norm.cdf(deltau/0.01),label="$\\sigma=0.01$")
plt.xlabel("$\\Delta_u$",fontsize=16)
plt.ylabel("probability",fontsize=16)
plt.grid()
plt.legend()
#plt.savefig("normcdf.pdf")

# %% [markdown]
# We simulate $m$ preferences using the above model and the true utility function.

# %%
n=15#number of objects
X=np.round(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])

sigma = 0.2# 0.05

m=40  

#generate preference pairs

Pairs=[]
for ii in range(m):
    np.random.seed(ii)
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        np.random.seed(103+ii)
        if np.random.rand(1)<norm.cdf((fun(X[i])-fun(X[j]))/sigma):
            Pairs.append([i,j])# i is preferred to j
        else:
            Pairs.append([j,i])# j is preferred to i
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)#remove any duplicate pair

# %% [markdown]
# We now run the erroneousPreference model to learn the utility function of Alice from the preference pairs.

# %%
# Data dictionary
data = {}
data["Pairs"]  = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.5*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 20.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([10.0]), 
                        'range':np.vstack([[0.01, 100.0]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


#define preference model 
model = erroneousPreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=60000, tune=5000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
# Out:
#   0%|          | 30/65000 [00:00<03:36, 299.75it/s]
# Iteration 0  -16.35875142233277
# {'lengthscale': {'value': array([1.08947051]), 'range': array([[ 0.1, 20. ]]), 'transform': <utility.paramz.logexp object at 0x7fcc42b5a160>}, 'variance': {'value': array([7.75874135]), 'range': array([[1.e-02, 1.e+02]]), 'transform': <utility.paramz.logexp object at 0x7fccb65097c0>}}
# 100%|██████████| 65000/65000 [01:04<00:00, 1012.54it/s]
# <ipython-input-228-cd41f4a2a4ed>:29: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.grid()
plt.savefig("Thermal_post_40_err_02.pdf")

# %%
az.plot_density(predictions[134,:]-predictions[107,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(20)-u(18)",fontsize=16)
plt.savefig("Thermal40_u20_18_err_02.pdf")

# %%
az.plot_density(predictions[67,:]-predictions[120,:],shade=0.4,hdi_prob=1,point_estimate=None)
plt.title("")
plt.xlabel("u(15)-u(19)",fontsize=16)
plt.savefig("Thermal40_u15_19_err.pdf")

# %% [markdown]
# # Gaussian Noise

# %%
n=15#number of objects
np.random.seed(2)
X=(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])
sigma=0.1
noise = sigma*np.random.randn(n)

m=80

#generate preference matrix
Pairs=[]
for ii in range(m):
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        if fun(X[i],noise[i])>fun(X[j],noise[j]):
            Pairs.append([i,j])# i is preferred to j
        elif fun(X[j],noise[j])>fun(X[i],noise[i]):
            Pairs.append([j,i])# j is preferred to i
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)

# %%
# data dictionary
data = {}
data["Pairs"] = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

# kernel parameter dictionary
params={'lengthscale': {'value':1.0*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 3.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
          'variance': {'value':np.array([1.0]), 
                        'range':np.vstack([[0.001, 50]]),
                        'transform': paramz.logexp()},
             'noise_variance': {'value':np.array([0.5]), 
                        'range':np.vstack([[0.001, 10.001]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


# define preference model 
model = gaussianNoisePreference(data,Kernel,params)
# compute hyperparameters
model.optimize_hyperparams(num_restarts=35)
print(model.params)
# sample from posterior
model.sample(nsamples=60000, tune=5000)
# predicted samples
predictions = model.predict(Xpred)
# compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
# plot the latent function mean and credible interval
plt.plot(Xpred[:,0],fun(Xpred[:,0]), label='true',color='C1')
plt.plot(Xpred[:,0],credib_int[:,1],color='C2', linestyle=':')
plt.plot(Xpred[:,0],credib_int[:,0],color='C2', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C2')
plt.xlabel("x",fontsize=16)
plt.ylabel("f(x)",fontsize=16)
plt.legend()
# Out:
# Iteration 0  -23.582504713979937
# Iteration 1  -25.14709476227243
# Iteration 2  -23.582514267938887
# Iteration 3  -25.147103037835784
# Iteration 4  -23.582504870081074
# Iteration 5  -25.14710170118375
# Iteration 6  -23.5825447653404
# Iteration 7  -23.582508178032164
# Iteration 8  -25.147097982249825
# Iteration 9  -25.14709058274637
# Iteration 10  -23.582574746468396
# Iteration 11  -25.147095067239775
# Iteration 12  -23.582504788298166
# Iteration 13  -23.58251733242216
# Iteration 14  -23.582504715312353
# Iteration 15  -29.50347987219951
# Iteration 16  -23.582505505581935
# Iteration 17  -25.1470951108078
# Iteration 18  -25.14704888633623
# Iteration 19  -23.582505150338143
# Iteration 20  -25.147098898987068
# Iteration 21  -23.582504902334513
# Iteration 22  -25.1470994640281
# Iteration 23  -25.147105558636667
# Iteration 24  -25.14710343948382
# Iteration 25  -25.147095897784894
# Iteration 26  -25.147102740792832
# Iteration 27  -25.146792097683
# Iteration 28  -23.58250500733692
# Iteration 29  -23.582505488231533
# Iteration 30  -23.582508040467253
# Iteration 31  -23.582504896842387
# Iteration 32  -23.582505007173012
# Iteration 33  -23.58253287432074
# /home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/gaussianNoisePreferenceFull.py:130: OptimizeWarning: Sparse constraint matrix detected; setting 'sparse':True.
#   res = linprog(np.zeros(A.shape[1]),A_ub=-A,b_ub=-b, bounds=[[0.,1]]*A.shape[1],method='interior-point' )
#   0%|          | 16/65000 [00:00<06:56, 156.05it/s]
# Iteration 34  -25.147103893977338
# {'lengthscale': {'value': array([1.82999777]), 'range': array([[0.1, 3. ]]), 'transform': <utility.paramz.logexp object at 0x7f6853c59790>}, 'variance': {'value': array([0.02871053]), 'range': array([[1.e-03, 5.e+01]]), 'transform': <utility.paramz.logexp object at 0x7f6853c594c0>}, 'noise_variance': {'value': array([0.0159821]), 'range': array([[1.0000e-03, 1.0001e+01]]), 'transform': <utility.paramz.logexp object at 0x7f6853c6b280>}}
# 100%|██████████| 65000/65000 [01:50<00:00, 587.07it/s]
# <ipython-input-152-4cc57ee1940a>:32: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.grid()
plt.savefig("Thermal_gaussiannoise.pdf")

# %%
# Data dictionary
data = {}
data["Pairs"]  = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.0*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 3.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([1.0]), 
                        'range':np.vstack([[0.01, 100.0]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


#define preference model 
model = erroneousPreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=55)
print(model.params)
#sample from posterior
model.sample(nsamples=60000, tune=5000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
# Out:
# Iteration 0  -25.15066627708034
# Iteration 1  -24.174602178136094
# Iteration 2  -24.174602393733696
# Iteration 3  -25.150665587198233
# Iteration 4  -24.17460219060056
# Iteration 5  -24.174602907665673
# Iteration 6  -25.150665610532187
# Iteration 7  -25.150665647451312
# Iteration 8  -24.174607876387906
# Iteration 9  -24.17460223416932
# Iteration 10  -24.174602179408105
# Iteration 11  -24.17460219759577
# Iteration 12  -25.15065841666307
# Iteration 13  -25.150665586339837
# Iteration 14  -24.174602507639374
# Iteration 15  -25.1506656141593
# Iteration 16  -24.178556034872546
# Iteration 17  -24.174602204116113
# Iteration 18  -25.150665587956173
# Iteration 19  -24.174602177827417
# Iteration 20  -25.150652399741723
# Iteration 21  -25.15066569638644
# Iteration 22  -25.15066558631952
# Iteration 23  -25.150665591875725
# Iteration 24  -25.150665870274572
# Iteration 25  -25.150665610273656
# Iteration 26  -25.15051785279184
# Iteration 27  -25.150665741463655
# Iteration 28  -25.15066562241033
# Iteration 29  -25.15066558633236
# Iteration 30  -25.1506655863881
# Iteration 31  -24.174602176802843
# Iteration 32  -24.17460268110272
# Iteration 33  -25.150666323460555
# Iteration 34  -25.15066558995575
# Iteration 35  -24.17460264289402
# Iteration 36  -25.150665165866204
# Iteration 37  -25.15066565410562
# Iteration 38  -25.15066558659695
# Iteration 39  -25.150552876163147
# Iteration 40  -24.174603126287906
# Iteration 41  -25.150665578382824
# Iteration 42  -24.174602523850414
# Iteration 43  -25.150665586291666
# Iteration 44  -25.15066558628631
# Iteration 45  -24.174602182045255
# Iteration 46  -25.150665586848923
# Iteration 47  -25.15066558624738
# Iteration 48  -25.150489363760997
# Iteration 49  -25.150658290784577
# Iteration 50  -24.174602208599772
# Iteration 51  -24.17460217753603
# Iteration 52  -24.174602550194663
# Iteration 53  -25.15066561053792
#   0%|          | 30/65000 [00:00<03:37, 298.60it/s]
# Iteration 54  -24.174602179389513
# {'lengthscale': {'value': array([0.74584236]), 'range': array([[0.1, 3. ]]), 'transform': <utility.paramz.logexp object at 0x7f26459c2490>}, 'variance': {'value': array([15.09604066]), 'range': array([[1.e-02, 1.e+02]]), 'transform': <utility.paramz.logexp object at 0x7f26459c2580>}}
# 100%|██████████| 65000/65000 [01:39<00:00, 652.85it/s]
# <ipython-input-6-32d5016027b5>:29: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x (Celsius)",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.grid()
plt.savefig("Thermal_gaussiannoise_erroneous.pdf")

# %% [markdown]
# # Backup

# %%
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
def plot_graph(Y,keepd=False):


    #plt.scatter(out[:, 0], out[:, 1])
    #plt.axis('equal');

    plt.figure(figsize=(7,7))
    G = nx.DiGraph(directed=True)
    G.add_edges_from(Y.tolist())
    #values = [val_map.get(node, -1.45) for node in G.nodes()]                      
    #graphviz_layout(G)
    if keepd==False:
        nx.draw_networkx(G,pos=graphviz_layout(G),cmap=plt.get_cmap('Wistia'),node_color='yellow') #, node_color = values)
    #plt.view()
    plt.savefig("net1.png")
    return G

plot_graph(np.vstack(listPairs).astype(int),keepd=False)

# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append('../')   
import numpy as np
from model.erroneousPreference import  erroneousPreference
from kernel import RBF
from utility import  paramz
from scipy.stats import norm
# for plotting
import matplotlib.pyplot as plt
import arviz as az

#generate data
np.random.seed(42)
bounds=[[10,27]]
def fun(x):
    return np.exp(-(x-15)**2/4)+1.2*np.exp(-(x-22)**2/4)
Xpred=np.linspace(bounds[0][0],bounds[0][1],200)[:,None]

n=20#number of objects
X=np.round(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])
m=25 # number of preferences



    
#generate preference matrix
Pairs=[]
for ii in range(m):
    np.random.seed(ii)
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        if  np.random.rand(1)<norm.cdf((fun(X[i])-fun(X[j]))/0.3):
            Pairs.append([i,j])# i is preferred to j
        else:
            Pairs.append([j,i])# j is preferred to i
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)


# data dictionary
data = {}
data["Pairs"] = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.5*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 6.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([5.0]), 
                        'range':np.vstack([[0.1, 100.01]]),
                        'transform': paramz.logexp()}#variance not used in exactPreference
          }


#define preference model 
model = erroneousPreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=3000, tune=6000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
#plot the latent function mean and credible interval
plt.plot(Xpred[:,0],2*fun(Xpred[:,0]), label='true',color='C1')
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.savefig("Thermal1.pdf")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   2%|▏         | 180/9000 [00:00<00:08, 983.28it/s]
# Iteration 0  -14.256503925936332
# {'lengthscale': {'value': array([2.23798939]), 'range': array([[0.1, 6. ]]), 'transform': <utility.paramz.logexp object at 0x7fa859fc3fd0>}, 'variance': {'value': array([5.93849553]), 'range': array([[1.0000e-01, 1.0001e+02]]), 'transform': <utility.paramz.logexp object at 0x7fa859fc3550>}}
# 100%|██████████| 9000/9000 [00:06<00:00, 1372.59it/s]
# <ipython-input-39-049adfe52f20>:70: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
norm.cdf((fun(X[2])-fun(X[1]))/0.1)
# Out:
# array([0.80807811])

# %%
listPairs=[np.round(list(i[:,0])) for i in list(X[Pairs])]
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt

def plot_graph(Y,keepd=False):


    #plt.scatter(out[:, 0], out[:, 1])
    #plt.axis('equal');

    plt.figure(figsize=(7,7))
    G = nx.DiGraph(directed=True)
    G.add_edges_from(Y.tolist())
    #values = [val_map.get(node, -1.45) for node in G.nodes()]                      
    #graphviz_layout(G)
    if keepd==False:
        nx.draw_networkx(G,pos=graphviz_layout(G),cmap=plt.get_cmap('Wistia'),node_color='yellow') #, node_color = values)
    #plt.view()
    plt.savefig("net2.png")
    return G

plot_graph(np.vstack(listPairs).astype(int),keepd=False)

# %%
# %load_ext autoreload
# %autoreload 2
import sys,os
sys.path.append('../')   
import numpy as np
from model.gaussianNoisePreferenceFull import  gaussianNoisePreference
from kernel import RBF
from utility import  paramz
from scipy.stats import norm
# for plotting
import matplotlib.pyplot as plt
import arviz as az

#generate data
np.random.seed(42)
bounds=[[10,27]]
def fun(x,ind,noise=1):
    np.random.seed(ind)
    return np.exp(-(x-15)**2/4)+1.2*np.exp(-(x-22)**2/4)+np.random.randn(1)*0.3*noise
Xpred=np.linspace(bounds[0][0],bounds[0][1],200)[:,None]

n=30#number of objects
X=np.round(np.linspace(bounds[0][0],bounds[0][1],n)[:,None])
m=65 # number of preferences



    
#generate preference matrix
Pairs=[]
for ii in range(m):
    np.random.seed(ii)
    i=np.random.randint(X.shape[0])
    j=np.random.randint(X.shape[0])
    if i != j:
        if  fun(X[i],i)-fun(X[j],j)>0:
            Pairs.append([i,j])# i is preferred to j
        else:
            Pairs.append([j,i])# j is preferred to i
Pairs, indices = np.unique(Pairs, axis=0, return_index=True)


# data dictionary
data = {}
data["Pairs"] = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.6*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 6.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([1.0]), 
                        'range':np.vstack([[1.0, 1.01]]),
                        'transform': paramz.logexp()},#
                     'noise_variance': {'value':np.array([0.09]), 
                        'range':np.vstack([[0.000001, 10.01]]),
                        'transform': paramz.logexp()}
          }


#define preference model 
model = gaussianNoisePreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=3000, tune=6000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
#plot the latent function mean and credible interval
plt.scatter(X[:,0],[fun(X[i,],i) for i in range(X.shape[0])], label='noisy',color='C1')
plt.plot(Xpred[:,0],fun(Xpred[:,0],0,noise=0), label='true',color='C1')
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.title("Gaussian Noise",fontsize=16)
plt.legend()
plt.savefig("Thermal2.pdf")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/benavoli/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/gaussianNoisePreferenceFull.py:130: OptimizeWarning: Sparse constraint matrix detected; setting 'sparse':True.
#   res = linprog(np.zeros(A.shape[1]),A_ub=-A,b_ub=-b, bounds=[[0.,1]]*A.shape[1],method='interior-point' )
#   0%|          | 39/9000 [00:00<00:23, 389.48it/s]
# Iteration 0  -28.459296703738882
# {'lengthscale': {'value': array([2.39795997]), 'range': array([[0.1, 6. ]]), 'transform': <utility.paramz.logexp object at 0x7fa88bdc1550>}, 'variance': {'value': array([1.]), 'range': array([[1.  , 1.01]]), 'transform': <utility.paramz.logexp object at 0x7fa88bea33d0>}, 'noise_variance': {'value': array([0.02972045]), 'range': array([[1.000e-06, 1.001e+01]]), 'transform': <utility.paramz.logexp object at 0x7fa859237f70>}}
# 100%|██████████| 9000/9000 [00:13<00:00, 651.10it/s]
# <ipython-input-80-4ab14dd82ecb>:74: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
0.3**2
# Out:
# 0.09

# %%
# data dictionary
data = {}
data["Pairs"] = Pairs
data["X"] = X

# define kernel and hyperparams
Kernel = RBF

#kernel parameter dictionary
params={'lengthscale': {'value':1.5*np.ones(data["X"].shape[1],float), 
                        'range':np.vstack([[0.1, 6.0]]*data["X"].shape[1]),
                        'transform': paramz.logexp()},
             'variance': {'value':np.array([1.0]), 
                        'range':np.vstack([[0.1, 100.01]]),
                        'transform': paramz.logexp()}
          }


#define preference model 
model = erroneousPreference(data,Kernel,params)
#compute hyperparameters
model.optimize_hyperparams(num_restarts=1)
print(model.params)
#sample from posterior
model.sample(nsamples=3000, tune=6000)
#predicted samples
predictions = model.predict(Xpred)
#compute the lower and upper credible intervals
credib_int = az.hdi(predictions.T,0.95)
#plot the latent function mean and credible interval
plt.scatter(X[:,0],[2*fun(X[i,],i) for i in range(X.shape[0])], label='noisy',color='C1')
plt.plot(Xpred[:,0],2*fun(Xpred[:,0],0,noise=0), label='true',color='C1')
plt.plot(Xpred[:,0],credib_int[:,1],color='C0', linestyle=':', label='95% CI')
plt.plot(Xpred[:,0],credib_int[:,0],color='C0', linestyle=':')
plt.plot(Xpred[:,0],np.mean(predictions,axis=1), label='mean',color='C0')
plt.xlabel("x",fontsize=16)
plt.ylabel("u(x)",fontsize=16);
plt.legend()
plt.title("Limit of discernability",fontsize=16)
plt.savefig("Thermal21.pdf")
# Out:
#   0%|          | 30/9000 [00:00<00:30, 295.05it/s]
# Iteration 0  -25.965008314127086
# {'lengthscale': {'value': array([1.62266672]), 'range': array([[0.1, 6. ]]), 'transform': <utility.paramz.logexp object at 0x7fa85903aee0>}, 'variance': {'value': array([3.96641662]), 'range': array([[1.0000e-01, 1.0001e+02]]), 'transform': <utility.paramz.logexp object at 0x7fa85903ae50>}}
# 100%|██████████| 9000/9000 [00:13<00:00, 646.96it/s]
# <ipython-input-81-850d601cce0e>:29: FutureWarning: hdi currently interprets 2d data as (draw, shape) but this will change in a future release to (chain, draw) for coherence with other functions
#   credib_int = az.hdi(predictions.T,0.95)

# %%
listPairs=[np.round(list(i[:,0])) for i in list(X[Pairs])]
import networkx as nx
from networkx.drawing.nx_agraph import graphviz_layout
from sklearn.manifold import MDS
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt

def plot_graph(Y,keepd=False):


    #plt.scatter(out[:, 0], out[:, 1])
    #plt.axis('equal');

    plt.figure(figsize=(7,7))
    G = nx.DiGraph(directed=True)
    G.add_edges_from(Y.tolist())
    #values = [val_map.get(node, -1.45) for node in G.nodes()]                      
    #graphviz_layout(G)
    if keepd==False:
        nx.draw_networkx(G,pos=graphviz_layout(G),cmap=plt.get_cmap('Wistia'),node_color='yellow') #, node_color = values)
    #plt.view()
    plt.savefig("net3.png")
    return G

plot_graph(np.vstack(listPairs).astype(int),keepd=False)
