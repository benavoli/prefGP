# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
sys.path.append('../')
from model.erroneousChoice_full import  erroneousChoice
from kernel import jaxrbf
from utility import  paramz
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import sys
#       5 sys.path.append('../')
# ----> 6 from model.erroneousChoice_full import  erroneousChoice
#       7 from kernel import jaxrbf
#       8 from utility import  paramz
#
# File ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/erroneousChoice_full.py:1
# ----> 1 from .abstractModel import abstractModelFull
#       2 import numpy as np
#       3 from inference import slice_sampler
#
# File ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/abstractModel.py:4
#       2 from abc import ABC, abstractmethod
#       3 from inference import laplace_generic as LAP
# ----> 4 from inference import laplace_sparse  as LAPsp
#       5 from inference import advi_sparse as ADVIS
#       6 from inference import advi_full as ADVIF
#
# ImportError: cannot import name 'laplace_sparse' from 'inference' (unknown location)

# %% [markdown]
# # Choosing Cupcakes

# %%
np.random.seed(1)
bounds=[[-0.25,1.25]]
def fun(x,sigma=0):
    u1 = np.exp(-(x-0.25)**2*15)+np.random.randn(len(x),1)*sigma #np.exp(-(x-0.25)**2*15)
    u2 = np.exp(-(x-0.75)**2*15)+np.random.randn(len(x),1)*sigma #np.exp(-(x-0.75)**2*15)
    return np.hstack([u1,u2])
Xpred=np.linspace(bounds[0][0],bounds[0][1],200)[:,None]

output = fun(Xpred,0.0)
plt.plot(Xpred[:,0],output[:,0],color='C1',label="u$_1$")
plt.plot(Xpred[:,0],output[:,1],color='C0',label="u$_2$")
plt.xlabel("x",fontsize=16)
plt.ylabel("$u_i(x)$",fontsize=16);
plt.grid()
plt.legend(fontsize=16)
plt.savefig("ChoiceCupcake.pdf")

# %% [markdown]
# # Learning from choice data
#
# We illustrate the overall model with an example. We consider the bi-dimensional utility function ${\bf u}(x)=[u_1(x),u_2(x)]$ with $x \in \mathbb{R}$.
# We use ${\bf u}$ to define a choice function via Pareto dominance. For instance, consider the set of options $A_k=\{x_1,x_2,x_3\}$, assume that ${\bf u}(x_1)=[1,0]$, ${\bf u}(x_2)=[0.54,-0.84]$, $
# {\bf u}(x_3)=[0,1]$,
# we have that $C(A_k)=\{x_1,x_3\}$ and $R(A_k)=A_k \backslash C(A_k)=\{x_2\}$. In fact, one can notice that  $[1,0]$ dominates  $[0.54,-0.84]$ on both the utilities, and $[1,0]$  and $[0,1]$ are incomparable.  We sample $30$ inputs $x_i$ at random in $[-0.25,1.25]$ and, using the above approach, we generate a dataset
# of $m=100$ random subsets $\{A_k\}_{k=1}^m$ of the 30 points each one of size $|A_k|=3$  and computed the corresponding choice pairs $(C(A_k),A_k)$ based on  ${\bf u}$ defined by `fun`.
#
# Note that, we use botorch (and torch) only to build the dataset (in particular we use the function `is_non_dominated`).

# %%
import torch
from botorch.utils.multi_objective import is_non_dominated

def is_pareto(X):
    return is_non_dominated(torch.from_numpy(X),deduplicate=False)

#generate CA RA sets
def make_CA_RA(x, y, rows=[],typeR='rational'):
    if len(rows)==0:
        rows=np.arange(x.shape[0])
    if typeR=='rational':
        acc = rows[is_pareto(y)]
        rej = rows[~ is_pareto(y)]
    elif typeR=='pseudo':
        indy = np.unique(np.argmax(y,axis=0))
        acc = rows[indy]
        rej = rows[np.setdiff1d(np.arange(x.shape[0]),indy)]
    return acc, rej

def make_observations(X, fun, nA, dimA,typeR='rational'):
    CA=[]
    RA=[]   
    ix = 0
    for i in range(nA):
        rows = np.random.permutation(np.arange(X.shape[0]))[0:dimA]
        x=X[rows,:]
        y=fun(x)
        acc,rej=make_CA_RA(x, y, rows,typeR=typeR)
        if len(acc)>0:
            CA.append(acc)
        else:
            CA.append([])
        if len(acc)<dimA:
            RA.append(rej)
        else:
            RA.append([])
        ix = ix+1
    return CA, RA


#generate data
np.random.seed(123)

# we randomly generate objects
n = 100 # number of objects
X = (np.vstack(bounds)[:,0]+np.random.rand(n,1)*(np.vstack(bounds)[:,1]-np.vstack(bounds)[:,0]))

# we randomly generate choice data
nA = 200 # number of choice sets
dimA = 3 # dimension of each choice set
CA, RA = make_observations(X, fun, nA, dimA,typeR='rational')
CA
# Out:
# [array([19, 61]),
#  array([27, 95]),
#  array([ 5, 72]),
#  array([44,  1]),
#  array([32, 73, 61]),
#  array([48, 29]),
#  array([95]),
#  array([82, 67]),
#  array([0]),
#  array([34, 97,  3]),
#  array([23, 54]),
#  array([98, 36]),
#  array([61, 24]),
#  array([ 9, 72]),
#  array([83, 31, 81]),
#  array([14, 75,  7]),
#  array([34, 57]),
#  array([63, 70]),
#  array([81, 88, 33]),
#  array([52, 99]),
#  array([99]),
#  array([73, 52, 54]),
#  array([98, 51]),
#  array([21, 92]),
#  array([82, 80]),
#  array([63,  9, 61]),
#  array([46, 79]),
#  array([12, 29]),
#  array([60, 13]),
#  array([14,  4]),
#  array([15, 53]),
#  array([57]),
#  array([ 1, 72]),
#  array([52, 39]),
#  array([86, 97]),
#  array([82, 50]),
#  array([ 1, 62]),
#  array([73, 30]),
#  array([52, 12]),
#  array([41, 57]),
#  array([90, 88]),
#  array([32, 95]),
#  array([20,  9]),
#  array([51, 12]),
#  array([88]),
#  array([66, 35]),
#  array([71, 96]),
#  array([44, 99]),
#  array([81,  8, 25]),
#  array([75, 12, 60]),
#  array([43, 37]),
#  array([34, 36, 72]),
#  array([40]),
#  array([83, 28,  4]),
#  array([54, 82, 93]),
#  array([89, 11]),
#  array([ 4, 88]),
#  array([46, 63, 12]),
#  array([86]),
#  array([92]),
#  array([33,  4, 43]),
#  array([94, 41]),
#  array([27,  4]),
#  array([59, 97,  3]),
#  array([14, 29, 95]),
#  array([80, 44]),
#  array([99,  8, 52]),
#  array([22,  2]),
#  array([ 3, 17]),
#  array([82]),
#  array([48, 17]),
#  array([97, 58]),
#  array([49,  9]),
#  array([90, 18, 92]),
#  array([23, 35]),
#  array([33,  5]),
#  array([80, 97]),
#  array([32, 86]),
#  array([ 7, 43, 52]),
#  array([8]),
#  array([72]),
#  array([40, 23]),
#  array([94, 45, 57]),
#  array([89, 42]),
#  array([11, 83, 39]),
#  array([28, 72]),
#  array([14, 82, 97]),
#  array([64, 56, 32]),
#  array([39, 20]),
#  array([28, 62]),
#  array([34, 46]),
#  array([86, 66, 36]),
#  array([86, 37]),
#  array([31, 53]),
#  array([8, 0]),
#  array([27]),
#  array([54, 60]),
#  array([10, 58]),
#  array([69,  5]),
#  array([ 3, 61]),
#  array([36,  9, 40]),
#  array([99, 81]),
#  array([36, 56]),
#  array([83, 92, 54]),
#  array([92]),
#  array([ 9, 33, 43]),
#  array([43, 24]),
#  array([92, 43, 22]),
#  array([99,  7]),
#  array([72,  2]),
#  array([25, 57]),
#  array([31, 22, 98]),
#  array([57]),
#  array([16, 53]),
#  array([86, 66]),
#  array([32, 15,  5]),
#  array([14, 55,  3]),
#  array([39]),
#  array([33, 28]),
#  array([75, 33, 43]),
#  array([35, 23]),
#  array([45, 56]),
#  array([54, 46]),
#  array([ 5, 26, 37]),
#  array([35]),
#  array([97, 14]),
#  array([10,  0]),
#  array([88, 59, 93]),
#  array([40]),
#  array([ 7, 76]),
#  array([72, 67, 39]),
#  array([10, 40, 97]),
#  array([14, 35]),
#  array([25, 15]),
#  array([49, 90, 68]),
#  array([76]),
#  array([ 3, 31]),
#  array([60, 83]),
#  array([24, 18, 12]),
#  array([77, 52, 49]),
#  array([19, 48]),
#  array([ 6, 80]),
#  array([ 8, 45, 95]),
#  array([29, 13]),
#  array([33, 80, 79]),
#  array([70, 29]),
#  array([34, 92, 44]),
#  array([89, 81]),
#  array([ 1, 62]),
#  array([46]),
#  array([89, 79, 52]),
#  array([37, 12]),
#  array([28]),
#  array([73, 12]),
#  array([ 1, 63]),
#  array([15, 54]),
#  array([89, 82]),
#  array([72, 90, 75]),
#  array([90, 87, 62]),
#  array([92, 85]),
#  array([28, 64]),
#  array([46,  4]),
#  array([24, 75, 88]),
#  array([44, 55]),
#  array([81, 19, 54]),
#  array([79, 97]),
#  array([36,  5]),
#  array([74, 51]),
#  array([95, 39]),
#  array([33, 32]),
#  array([24]),
#  array([3, 5]),
#  array([63, 76]),
#  array([54, 32]),
#  array([49, 80]),
#  array([10,  4]),
#  array([ 9, 66, 89]),
#  array([ 8, 64]),
#  array([63,  2]),
#  array([40,  1]),
#  array([31, 39, 57]),
#  array([29]),
#  array([82, 53]),
#  array([68, 79, 19]),
#  array([28, 40]),
#  array([54]),
#  array([87, 64]),
#  array([ 0, 39]),
#  array([73, 25]),
#  array([78, 40, 63]),
#  array([99, 66]),
#  array([62, 89]),
#  array([23, 65, 57]),
#  array([36, 29]),
#  array([75, 30]),
#  array([89,  7,  5]),
#  array([88, 60]),
#  array([88, 47]),
#  array([49]),
#  array([99, 90])]

# %% [markdown]
# ## Fixed latent dimension
#
# The following code allows us to learn a choice function from choice-data. We have to select the latent dimension `latent_dim`, which represents the number of utility functions. Similarly to GP processes for multiclass classification, we model each  latent utility function in the vector ${\bf u}({\bf x})=[u_1({\bf x}),\dots,u_{d}({\bf x})]^\top$ as an independent GP:
#
# $$
#  u_i({\bf x}) \sim \text{GP}_i(0,k_i({\bf x},{\bf x}')), ~~~~i=1,2,\dots,d.
# $$
#
#  Each GP is fully specified by its kernel function $k_i(\cdot,\cdot)$, which defines the covariance of the latent function between any two points. The model parameters are the kernel parameters (lengthscales) in $k_i(\cdot,\cdot)$, and the variance. These parameters must be initiliased and then they are optimised using variational inference.

# %%
#choice data
data={'X': X,#objects
      'CA': CA,#choiced objects
      'RA': RA,#rejected objects
      'dimA':dimA# dimension of the choice set
          }

# number of latent utilities
latent_dim=2

# define kernel 
Kernel = jaxrbf.RBF
#hyperparameters of the kernel
params = {'lengthscale_0': {'value':0.77*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 3.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_0': {'value':np.array([50.0]), 
                            'range':np.vstack([[1.0, 100.0]]),
                            'transform': paramz.logexp()},
          'lengthscale_1': {'value':0.77*np.ones(data["X"].shape[1],float), 
                            'range':np.vstack([[0.1, 3.0]]*data["X"].shape[1]),
                            'transform': paramz.logexp()},
           'variance_1': {'value':np.array([50.0]), 
                            'range':np.vstack([[1.0, 100.0]]),
                            'transform': paramz.logexp()}
              }



# define choice model 
model = erroneousChoice(data,Kernel,params,latent_dim,typeR="rational",jitter=1e-6)
# compute variational inference and estimate hyperparameters
model.optimize_hyperparams(niterations=3000,kernel_hypers_fixed=False,  diagonal=False)
print(model.params)
# Out:
# 80.32387060432849
# 80.8738715801392
#  lower bound 314.39903205377357:   9%|▍    | 280/3000 [20:55<3:23:12,  4.48s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[73], line 33
#      31 model = erroneousChoice(data,Kernel,params,latent_dim,typeR="rational",jitter=1e-6)
#      32 # compute variational inference and estimate hyperparameters
# ---> 33 model.optimize_hyperparams(niterations=3000,kernel_hypers_fixed=False,  diagonal=False)
#      34 print(model.params)
#
# File ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../model/abstractModel.py:47, in abstractModelFull.optimize_hyperparams(self, num_restarts, niterations, kernel_hypers_fixed, init_f, diagonal)
#      42 elif self.inf_method=='advi':
#      43     infer = ADVIF.inference_advi(self.data,
#      44                                   self.Kernel,
#      45                                   self.params,
#      46                                   self._log_likelihood)
# ---> 47     infer.optimize(niterations,
#      48                    kernel_hypers_fixed=kernel_hypers_fixed,
#      49                    init_f=init_f,diagonal=diagonal)
#      50     self.meanVI = infer.meanVI
#      51     self.SigmaVI = infer.SigmaVI
#
# File ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py:263, in inference_advi.optimize(self, niterations, progress, kernel_hypers_fixed, init_f, diagonal)
#     260 init_params_kernel,bounds_hyper=dic.fit_transform(self.params)
#     262 loglike =self._log_like()
# --> 263 f, Sigma, log_kernel_hypers, advi_params = self.advi(niterations,loglike,
#     264                                                      init_params_kernel,
#     265                                                      kernel_hypers_fixed=kernel_hypers_fixed,
#     266                                                      init_f=init_f,diagonal=diagonal)
#     267 self.meanVI = f[:,None]
#     268 self.SigmaVI = Sigma
#
# File ~/Dropbox/DropBoxRunning/SkewNormal_all/Python_preferences_GP/GPpref/notebooks/../inference/advi_full.py:86, in inference_advi.advi(self, niterations, loglike, init_params_kernel, progress, kernel_hypers_fixed, diagonal, init_f)
#      84 rng = random.PRNGKey(rnd)
#      85 f0= jax.random.normal(rng,(K.shape[0],))*0.5
# ---> 86 res=minimize(jit(logjoint),f0,
#      87      #bounds=[[-0.1,0.1]]*len(f0),
#      88      options={'maxiter': 300}, method="BFGS")
#      89 print(res.fun)
#      90 if res.fun<best_f:
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/scipy/optimize/minimize.py:107, in minimize(fun, x0, args, method, tol, options)
#     104 fun_with_args = lambda x: fun(x, *args)
#     106 if method.lower() == 'bfgs':
# --> 107   results = minimize_bfgs(fun_with_args, x0, **options)
#     108   success = results.converged & jnp.logical_not(results.failed)
#     109   return OptimizeResults(x=results.x_k,
#     110                          success=success,
#     111                          status=results.status,
#    (...)
#     116                          njev=results.ngev,
#     117                          nit=results.k)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/scipy/optimize/bfgs.py:164, in minimize_bfgs(fun, x0, maxiter, norm, gtol, line_search_maxiter)
#     153   state = state._replace(
#     154       converged=converged,
#     155       k=state.k + 1,
#    (...)
#     160       old_old_fval=state.f_k,
#     161   )
#     162   return state
# --> 164 state = lax.while_loop(cond_fun, body_fun, state)
#     165 status = jnp.where(
#     166     state.converged,
#     167     0,  # converged
#    (...)
#     176     )
#     177 )
#     178 state = state._replace(status=status)
#
#     [... skipping hidden 1 frame]
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/lax/control_flow/loops.py:1243, in while_loop(cond_fun, body_fun, init_val)
#    1240 if disallowed_effects:
#    1241   raise NotImplementedError(
#    1242       f'Effects not supported in `while`: {disallowed_effects}')
# -> 1243 outs = while_p.bind(*cond_consts, *body_consts, *init_vals,
#    1244                     cond_nconsts=len(cond_consts), cond_jaxpr=cond_jaxpr,
#    1245                     body_nconsts=len(body_consts), body_jaxpr=body_jaxpr)
#    1246 return tree_unflatten(body_tree, outs)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/core.py:2656, in AxisPrimitive.bind(self, *args, **params)
#    2652 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2653                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2654 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2655              else axis_main.with_cur_sublevel())
# -> 2656 return self.bind_with_trace(top_trace, args, params)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/core.py:388, in Primitive.bind_with_trace(self, trace, args, params)
#     387 def bind_with_trace(self, trace, args, params):
# --> 388   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     389   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/core.py:868, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     867 def process_primitive(self, primitive, tracers, params):
# --> 868   return primitive.impl(*tracers, **params)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/dispatch.py:128, in apply_primitive(prim, *args, **params)
#     126   in_avals, in_shardings = util.unzip2([_arg_spec(a) for a in args])
#     127   in_tree = tree_util.tree_structure(args)
# --> 128   compiled_fun = xla_primitive_callable(
#     129       prim, in_avals, in_tree, OrigShardings(in_shardings), **params)
#     130 except pxla.DeviceAssignmentMismatchError as e:
#     131   fails, = e.args
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/util.py:284, in cache.<locals>.wrap.<locals>.wrapper(*args, **kwargs)
#     282   return f(*args, **kwargs)
#     283 else:
# --> 284   return cached(config.config._trace_context(), *args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/util.py:277, in cache.<locals>.wrap.<locals>.cached(_, *args, **kwargs)
#     275 @functools.lru_cache(max_size)
#     276 def cached(_, *args, **kwargs):
# --> 277   return f(*args, **kwargs)
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/dispatch.py:161, in xla_primitive_callable(prim, in_avals, in_tree, orig_in_shardings, **params)
#     156 flat_fun, out_tree = api_util.flatten_fun_nokwargs(wrapped_fun, in_tree)
#     157 computation = sharded_lowering(
#     158     flat_fun, prim.name, donated_invars, keep_unused=False,
#     159     inline=True, in_avals=in_avals, in_shardings=orig_in_shardings.shardings,
#     160     lowering_parameters=mlir.LoweringParameters())
# --> 161 compiled = computation.compile()
#     162 if xla_extension_version >= 192:
#     163   if config.disable_jit.value:
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2258, in MeshComputation.compile(self, compiler_options)
#    2256 def compile(self, compiler_options=None) -> MeshExecutable:
#    2257   if self._executable is None or compiler_options is not None:
# -> 2258     executable = UnloadedMeshExecutable.from_hlo(
#    2259         self._name, self._hlo, **self.compile_args,
#    2260         compiler_options=compiler_options)
#    2261     if compiler_options is None:
#    2262       self._executable = executable
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2606, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2603       mesh = i.mesh  # type: ignore
#    2604       break
# -> 2606 xla_executable, compile_options = _cached_compilation(
#    2607     hlo, name, mesh, spmd_lowering,
#    2608     tuple_args, auto_spmd_lowering, allow_prop_to_outputs,
#    2609     tuple(host_callbacks), backend, da, pmap_nreps,
#    2610     compiler_options_keys, compiler_options_values)
#    2612 if hasattr(backend, "compile_replicated"):
#    2613   semantics_in_shardings = SemanticallyEqualShardings(in_shardings)  # type: ignore
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/interpreters/pxla.py:2513, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, _allow_propagation_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2508   return None, compile_options
#    2510 with dispatch.log_elapsed_time(
#    2511     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2512     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2513   xla_executable = compiler.compile_or_get_cached(
#    2514       backend, computation, dev, compile_options, host_callbacks)
#    2515 return xla_executable, compile_options
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/compiler.py:295, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     291 use_compilation_cache = (compilation_cache.is_initialized() and
#     292                          backend.platform in supported_platforms)
#     294 if not use_compilation_cache:
# --> 295   return backend_compile(backend, computation, compile_options,
#     296                          host_callbacks)
#     298 global _cache_used
#     299 if not _cache_used:
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/profiler.py:340, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     337 @wraps(func)
#     338 def wrapper(*args, **kwargs):
#     339   with TraceAnnotation(name, **decorator_kwargs):
# --> 340     return func(*args, **kwargs)
#     341   return wrapper
#
# File ~/anaconda3/envs/myenv/lib/python3.9/site-packages/jax/_src/compiler.py:255, in backend_compile(backend, module, options, host_callbacks)
#     250   return backend.compile(built_c, compile_options=options,
#     251                          host_callbacks=host_callbacks)
#     252 # Some backends don't have `host_callbacks` option yet
#     253 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     254 # to take in `host_callbacks`
# --> 255 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
predictions = model.predict_VI(Xpred)

mean=predictions[0]
Sigma=predictions[1]
mean1=mean[0:Xpred.shape[0]]
mean2=mean[Xpred.shape[0]:]
d=np.sqrt(np.diag(Sigma[0:Xpred.shape[0],0:Xpred.shape[0]]))[:,None]
cred_int1=mean1+2*np.hstack([-d,d])
d=np.sqrt(np.diag(Sigma[Xpred.shape[0]:,Xpred.shape[0]:]))[:,None]
cred_int2=mean2+2*np.hstack([-d,d])
plt.plot(Xpred[:,0],mean1,color='C0',label="$E[u_1]$")
plt.plot(Xpred[:,0],mean2,color='C1',label="$E[u_2]$")
plt.fill_between(Xpred[:,0],cred_int1[:,0],cred_int1[:,1],
                 color='C0', linestyle=':',alpha=0.15)

plt.fill_between(Xpred[:,0],cred_int2[:,0],cred_int2[:,1],color='C1', linestyle=':',alpha=0.15)

plt.xlabel("x", fontsize=16)
plt.ylabel("u", fontsize=16, rotation=0)
plt.legend(fontsize=16,loc='lower left')
#plt.savefig("EstimatedCupcakes_pseudo_pseudo.pdf")

# %%
from scipy.stats import multivariate_normal
mean = predictions[0]
Sigma = predictions[1]
#first utility
samples = multivariate_normal(mean[:,0],Sigma+1e-4*np.eye(Sigma.shape[0])).rvs(100)
i =50
u1 = samples[i][0:Xpred.shape[0]]
u2 = samples[i][Xpred.shape[0]:]
plt.plot(Xpred[:,0],u1,color='C0',label="$E[u_1]$")
plt.plot(Xpred[:,0],u2,color='C1',label="$E[u_2]$")
plt.legend()
#plt.savefig("Estimatedcupcakesamples.pdf")

# %% [markdown]
# ## Learning the latent dimension
# To learn the latent dimension, we will use the PSIS-LOO. We will try all values of the latent dimension between 1 and 4 and select the value which has lowest PSIS-LOO.

# %%
import model_selection as ms

Scores=ms.model_Selection(X,dimA,  CA_tr=CA, RA_tr=RA, minm=1,maxm=4)
Scores

# %% [markdown]
# The best dimension is $2$, equal to the true dimension.
